# %% [markdown]
# <a href="https://colab.research.google.com/github/matt-cornelius/Flip/blob/main/Assignment_1_MLP_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1: Multi Layer Perceptron (MLP) Classifier
#
# # Student name: Matt Cornelius
#
#
# Based (very loosely) on a MLP demo by Thomas Summe, Zheng Ning, Adam Czajka (February 2023)
#
# Updated Jan 20, 2025
#
# In this assignment you will implement (starting from some Prof-provided "scaffolding") a multi-layer perceptron classifier, building on the single-neuron classifier you explored in the first Practical class.
#
# ### Logistics
# **When you first open this notebook, save it in your Github repo**. Open it from Github when you're working on it. Commit it often (commit messages can be short but you have to enter something...). The notebook submitted closest to, but before, the assignment due date will be the one graded.
#
# ###AI policy for this assignment
# I hope and expect that you will consult on-line resources including AIs as you attack this problem - but **cite your sources** below (I provide an example), and make sure you understand how your solution works!
#
# ### Resources used in my solution (students replace the material below):
#  * https://machinelearningmastery.com/building-a-multiclass-classification-model-in-pytorch/ - I used Pytorch's one-hot encoder rather than sklearn's. I avoided using Pandas because we already have a nice dictionary of data.

# %% [markdown]
# ## Problem Setup
#
# In Practical 1, you used a single neuron as a _binary classifier_ -- we trained the neuron's output to be high or low based on which class the 128-D input came from.
#
# We're working with the same data here -- but your classifier is going to choose between more than two classes.
#
# How does this differ?
#  + **A more complex hidden layer**: you'll have a *set* of linear neurons receiving the 128-D inputs and computing linear functions from them, not just one.
#  + **An additional "output" layer**: you'll have an additional layer containing neurons that combine the outputs of the hidden layer, and we'll train them to produce a one-hot style class indication.
#  + **One-hot class encoding**: The class label will be encoded as a one-hot vector rather than a scalar with the class label
#  + **Cross-Entropy Loss**: Since this is a multi-class problem (more than two classes to choose from), we can't use the binary cross-entropy loss for training; we'll use its more general form.
#  + **GPU**: you'll use code that uses the GPU functionality of Pytorch in this assignment if you're running on a system with a GPU in it - so you'll need to make sure you're running on a GPU instance to take advantage of it.
#
# First, we import the things we need. Add more imports here if you need them. You'll see code at the bottom that will assign 'cuda' or 'cpu' to the variable `device`, which we will use later.

# %%
import os
import sys
import random
import gdown

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
import torchsummary
import numpy as np

import matplotlib.pyplot as plt
import tqdm.notebook as tqdm

# some housekeeping; random stuff & cuda
_ = torch.random.seed()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Executing NN code on {device}')
# Out:
# Executing NN code on cuda

# %% [markdown]
# ## Data set
#
# Get the FR data from Practical 1

# %%
# download data from Google Drive using gdown

url = 'https://drive.google.com/uc?id=19heLsvTf6AHj9irshCS-zdhTeL-w-Zc7'
localname = 'embeddingsbysubject.npy'
if os.path.exists(localname):
    print(f'{localname} already exists. Delete if you want to re-download it.')
else:
    gdown.download(url,localname)

# load the file
# the file contains a numpy array with one element: a ginormous dict.
# the .item() method pries the dict out of the array

d = np.load(localname,allow_pickle=True).item()
# Out:
# embeddingsbysubject.npy already exists. Delete if you want to re-download it.

# %% [markdown]
# ## A utility function to get the `n` subject-IDs with the most data
#
# `d` is a dictionary. Subject-ID strings (_e.g._, `'02463'`) are the keys, and for each key, the value is a numpy array with shape `(nvecs,128)`; that is, `nvecs` rows and 128 columns. `nvecs` is the number of data points (embeddings) for the subject. Each embedding comes from an image, so `nvecs` is also the number of images processed for that subject. The 128-dimensional vector is a representation for the subject's face in that image (it's computed by a convolutional neural net).
#
# Give this function the dictionary and, optionally, a value for `n` (the default is 10). It will return a dictionary containing the (key,value) pairs with the `n` largest number of embeddings.

# %%
def get_top_n(d,n=10):
    """
    given the dict d whose keys map to 2D numpy arrays, return a subset
    dictionary with the n keys that have the largest number of rows.
    In this notebook, 'return the n subjects with the largest number of
    face embeddings or, equivalently, images seen.'
    """
    skeys = sorted(list(d.keys()),key=lambda k:d[k].shape[0],reverse=True)
    return skeys[:n]

# %%
# print out the top ten keys and their sample counts
k_top_10 = get_top_n(d,n=10)
print(f'Top 10 subject IDs and their sample counts:')
print([[k,d[k].shape[0]] for k in k_top_10])
# Out:
# Top 10 subject IDs and their sample counts:
# [['04202', 221], ['04514', 217], ['04530', 214], ['02463', 213], ['04557', 209], ['04495', 209], ['04203', 205], ['04580', 204], ['04385', 203], ['04470', 200]]

# %% [markdown]
# ## A dataset class
#
# This code constructs a Pytorch `Dataset` from a subset of the data in the dictionary. When instantiating it, supply the dict containing the data and a list of keys of the subjects you want in the `Dataset`.
#
# Note: the labels scored with this class (and returned from its `__getitem__()` method) are **one-hot** encodings. If you initialize it with `k` subject IDs (keys), then the label returned by `__getitem__()` will be a `k`-element vector with exactly one nonzero element.
#
# This class has an introspection method called `sample_size()` that returns the number of dimensions of each sample (embedding). This quantity could vary if data from a different feature extractor was used (some face embeddings are 512 dimensions or larger), and since we will provide these samples to the input of a neural network, the method gives us a "clean" way to get it.
#
# Note: you don't have to call the superclass constructor when you're subclassing `torch.utils.data.Dataset` because there is no constructor for the superclass (it's abstract and doesn't need to do anything). Feel free to call it if you like to be rigorous. Down below, you'll subclass `torch.nn.Module` to define your custom neural net class, and a superclass constructor call is mandatory there.

# %%
# Dataset

class ManyClassEmbeddingData(torch.utils.data.Dataset):
    """A dataset obtained from a dictionary where keys (class names) map to
    2D numpy arrays with shape (nembeddings,dim)"""
    def __init__(self,d,keys):
        """init method: select the data with the given keys. Keys are unique
        so will sort stably."""
        self.keys = keys.copy()
        self.data = np.vstack([d[k] for k in keys])
        # nested list of labels for label vector
        labs = [[i]*d[k].shape[0] for (i,k) in enumerate(keys)]
        # stack it and generate one-hot encodings
        self.label = torch.nn.functional.one_hot(torch.tensor(np.hstack(labs)))

    def sample_size(self):
        return self.data[0].shape[0]

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self,idx):
        return self.data[idx],self.label[idx]

# %% [markdown]
# # Task 1: Get some data
#
# Create an instance of `ManyClassEmbeddingData` for the subject-IDs (keys) with the `nclasses = 10` largest numbers of samples. Use the `get_top_n()` function to get those keys and supply the list of keys to the constructor along with the dictionary of data. Also, create a variable `input_size` and set it equal to the output of the `sample_size()` method for your `ManyClassEmbeddingData` instance.

# %%
# Assume d is your dictionary containing the data
def get_top_n(d, n=10):
    skeys = sorted(list(d.keys()), key=lambda k: d[k].shape[0], reverse=True)
    return skeys[:n]

# Get the top 10 keys based on the number of samples
top_keys = get_top_n(d, n=10)

# Create an instance of ManyClassEmbeddingData with the top keys
dataset = ManyClassEmbeddingData(d, top_keys)

# Set input_size to the sample size of the dataset
input_size = dataset.sample_size()

# %% [markdown]
# ## Task 2: Set up data loaders
#
# In the code cell below:
#  + Define and initialize a variable: `b_size = 64`
#  + Use what you learned from Practical 1 to divide your data set into three pieces:
#    + `train_data` with 55% of the data
#    + `test_data` with 20% of the data
#    + `validation_data` with 25% of the data.
#
#    Wrap them individually with `DataLoaders`, specifying `shuffle=True` and `batch_size = b_size`.

# %%
# Define batch size
b_size = 64

# Define split ratios
total_size = len(dataset)
train_size = int(0.55 * total_size)
test_size = int(0.20 * total_size)
val_size = total_size - train_size - test_size  # Ensure all data is used

# Split dataset
train_data, test_data, validation_data = random_split(dataset, [train_size, test_size, val_size])

# Wrap datasets in DataLoaders
train_loader = DataLoader(train_data, batch_size=b_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=b_size, shuffle=True)
val_loader = DataLoader(validation_data, batch_size=b_size, shuffle=True)

# %% [markdown]
# # Task 3: Define a neural net
#
# Define a class `MLP` that inherits from `torch.nn.Module`. The class has these methods:
#  + `__init__(self,input_dim,hidden_dim,output_dim)` has two `torch.nn.Linear` layers with a `torch.nn.ReLU` activation function applied to the output of the first layer. The first linear layer has `input_dim` inputs and `hidden_dim` outputs; the second linear layer has `hidden_dim` inputs and `nclasses` outputs.
#  + `forward(self,input)` sends the `input` to the first layer, runs the `ReLU` on the result, feeds the output of `ReLU` to the second linear layer and returns the output of the second linear layer.
#
# There are lots of ways to implement this. Good designs set up the network in the constructor (`__init__()`) and use it in the `forward()` method. For what it's worth, I like to wrap the layers and activations in an instance of class `torch.nn.Sequential` in the constructor.  Make sure you invoke the superclass's constructor as your constructor's first action.

# %%
# STUDENT CODE GOES HERE

class MLP(torch.nn.Module):
    def __init__(self,input_dim,hidden_dim,output_dim):
        """ initialize the MLP with n-dimensional input, hidden_dim units in the
        hidden layer, and output_dim units in the output layer. output_dim
        is normally the number of classes."""
        super(MLP, self).__init__()

        # Define the network layers using nn.Sequential
        self.network = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self,input):
        """return the output response of the network  to an input."""
        return self.network(input)

# %% [markdown]
# # Freebie: an evaluation function
#
# The function below takes a model (an instence of `MLP`; it could be trained, doesn't have to be) and a `DataLoader` instance, and feeds all of the data through the net, keeping track of its output. From the net's output (an estimated label) and the known correct label for each sample, both expressed as a one-hot encoding of the class number, it reports the fraction of samples that were crrectly classified. We want this to be 1.0, ideally.
#
# You're not being asked to code this (this time) because of some "fiddly bits", including
#  + the batching of samples delivered from the loader (all of the variables in the inner loop are vectors; `X` is a matrix).
#  + the use of `.float().to(device)` to ensure the data is in single precision floating point format, and move it from CPU RAM to GPU RAM (if you're running on a GPU, of course). The model had previously been moved to the device before training, and torch requires you to explicitly move data to the model (and sometimes move results in the reverse direction).
#  + The somewhat cryptic comparison of estimated class labels to true class labels and conversion to a vector with 1 elements for correct classifications and 0s for incorrect ones).

# %%
# evaluates the model's current state on some data that we get from a
# DataLoader (should NOT be evaluated on training data!)

def evaluate(model, loader):
    model.eval() # no training
    corrs = [] # list containing a 1 for each correct prediction and a 0 for each mistake
    for X,y in loader: # data loader gives us a batch; data sample and one-hot encoded class label
        X = X.float().to(device) # move data and label to GPU if we're using one
        y = y.float().to(device)
        y_pred = model(X) # feed the data to the model, get OHE prediction
        # this code compares the net's output OHE to the ground truth
        # OHE and assigns a 1 for each case where they agree and a 0 when they don't
        corr = (torch.argmax(y_pred,1) == torch.argmax(y,1)).float()
        corrs += corr # append to the running list
    # return the classification accuracy: num correct/total num
    acc = sum(corrs)/len(corrs)
    return acc

# %% [markdown]
# # Task 4: Set up and run an experiment
#
# This task has a lot going on, so the description is lengthy.
#
# In the cell below, add code that performs an experiment. It's very useful to do this in a single cell during the test process.  Among other reasons, it ensures that you have a fresh instance of `MLP` each time you run it (if you want to retrain an `MLP` or any net in PyTorch, you have to explicitly reset its weights to all zeros or random otherwise you won't be training from scratch; you'll be "fine-tuning").
#
# 1. Define some parameters: `epoch_max = 1000`; `input_dim = input_size` as defined above, `hidden_dim=5`, and `output_dim = nclasses` as specified above.
# 2. Instantiate `MLP` with the proper values. Assuming you named the instance `mlp`, then execute `mlp = mlp.to(device)`. If you don't to this, it won't run on the GPU if you're using one!
# 3. Run `torchsummary.summary(mlp,input_size=(input_dim,))`. There's a question on its output below.
# 4. Define the loss function: `loss_fn = torch.nn.CrossEntropyLoss()`. Think of that statement as defining an instance of an object - the parentheses are important.
# 5. Define `learning_rate` to be some number between 0.005 and 0.05`.
# 6. The final setup step is to choose an optimizer that guides the gradient descent procedure that is used dring training.
#  + If your family name begins with the letters A through J, use `optimizer = torch.optim.SGD(mlp.parameters(),lr=learning_rate)`
#  + if your family name begins with the letters K through Z, use `optimizer = torch.optim.Adam(mlp.parameters(),lr=learning_rate)`
#
# Now, implement the training loop.
# 1. Define a loop variable `epoch` and have it run from 0 to `max_epochs` times. You might want to use `tqdm` to show a nice progress bar to watch as this runs.  Within this outer loop, do this:
#  1.  initialize `running_loss to 0`. once all the batches for this epoch are done, it will contain the overall loss value.
#  1. invoke `mlp.train()` to put the net in training mode. Basically, backpropagation won't work if you don't do this (and you'll notice).
#  1.  Iterate over the **training** dataloader; you get a batch `(X,y)` where `X` is a matrix of samples and `y` is a vector of known class labels, one for each sample - each one of the labels is an OHE. Within this inner loop, do this:
#     1. `optimizer.zero_grad()` to reset the gradients stored with all the internal data to 0.
#     2. use `.float().to(device)` to convert both `X` and `y` to floating point and move them to the GPU if you're using one. The idiom here is `X = X.float().to(device)`
#     3. put X through `mlp` to get `ypred`, the predicted class label.
#     4. calculate the loss: `loss = loss_fn(ypred,y)` (it's not a number, it's an object; The numerical value of loss is `loss.item()`.)
#     5. backpropagate the error: call `loss.backward()`
#     6. update the optimizer: call `optimizer.step()`
#     7. update the running loss: `running_loss += loss.item()`
#  2. (still within an iteration of `epoch`) Calculate the accuracy of the MLP on the validation set at this iteration by sending it and the **validation** loader to the `evaluate()` function above. Print out the return value from `evaluate()` and print out the `running_loss` as well.
# 3. (Done with all of the training epochs) Run `evaluate()` on the trained(?) net and the **test** loader and print the result.
#
# **After all that implementation work**: run the cell, and report the final accuracy on the test set in the area below labeled `Answer`, where indicated.
#
# **Additional answering**: In the area below labeled `Answer`, enter a formula for the number of parameters at each level reported by `torchsummary.summary()`. (i.e., thenumbers in the `Param #` column). The formula should be in terms of one or more of the parameters above and should be exact. Remember that there's a bias input to every neuron as well!  In the same text area, explain why ReLU has no parameters.
#
# Answer:
# 1. answer here
# 2. answer here

# %%
# STUDENT CODE GOES HERE

# 1. define parameters
epoch_max = 1000
input_dim = dataset.sample_size()
hidden_dim = 5
output_dim = len(top_keys)

# 2. instantiate
mlp = MLP(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim)
mlp = mlp.to(device)

# 3. summary
torchsummary.summary(mlp,input_size=(input_dim,))

# 4. loss function
loss_fn = torch.nn.CrossEntropyLoss()

# 5. Learning rate
learning_rate = 0.01

# 6. optimizer
optimizer = torch.optim.SGD(mlp.parameters(),lr=learning_rate)

# Training loop
# 1. loop variable
for epoch in tqdm.trange(epoch_max):
    # 1.1 running loss
    running_loss = 0.0
    # 1.2 training mode
    mlp.train()
    # 1.3 loop over batches
    for X,y in train_loader:
        # 1.3.1 reset gradients
        optimizer.zero_grad()
        # 1.3.2 convert data and labels to float and move them to the device
        X, y = X.float().to(device), y.float().to(device)
        # 1.3.3 provide X to mlp() to get ypred predicted labels
        y_pred = mlp(X)
        # 1.4.4 get loss from ypred and y
        loss = loss_fn(y_pred, y)
        # 1.4.5 propagate loss backward through the graph
        loss.backward()
        # 1.4.6 update the optimizer
        optimizer.step()
        # update running loss
        running_loss += loss.item()
    # 1.4 calculate & print accuracy on validation set
    val_accuracy = evaluate(mlp, val_loader)
    print(f"Epoch {epoch+1}/{epoch_max} - Loss: {running_loss:.4f} - Val Accuracy: {val_accuracy:.4f}")

# 2. calculate & print test accuracy
test_accuracy = evaluate(mlp, test_loader)
print(f"Final Test Accuracy: {test_accuracy:.4f}")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 5]             645
#               ReLU-2                    [-1, 5]               0
#             Linear-3                   [-1, 10]              60
# ================================================================
# Total params: 705
# Trainable params: 705
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1/1000 - Loss: 42.5583 - Val Accuracy: 0.0916
# Epoch 2/1000 - Loss: 42.5040 - Val Accuracy: 0.1011
# Epoch 3/1000 - Loss: 42.4525 - Val Accuracy: 0.0916
# Epoch 4/1000 - Loss: 42.4033 - Val Accuracy: 0.0897
# Epoch 5/1000 - Loss: 42.3620 - Val Accuracy: 0.0897
# Epoch 6/1000 - Loss: 42.3278 - Val Accuracy: 0.0897
# Epoch 7/1000 - Loss: 42.2960 - Val Accuracy: 0.0897
# Epoch 8/1000 - Loss: 42.2655 - Val Accuracy: 0.0897
# Epoch 9/1000 - Loss: 42.2363 - Val Accuracy: 0.0897
# Epoch 10/1000 - Loss: 42.2075 - Val Accuracy: 0.0897
# Epoch 11/1000 - Loss: 42.1809 - Val Accuracy: 0.0897
# Epoch 12/1000 - Loss: 42.1548 - Val Accuracy: 0.0897
# Epoch 13/1000 - Loss: 42.1291 - Val Accuracy: 0.0897
# Epoch 14/1000 - Loss: 42.1046 - Val Accuracy: 0.0897
# Epoch 15/1000 - Loss: 42.0813 - Val Accuracy: 0.0897
# Epoch 16/1000 - Loss: 42.0581 - Val Accuracy: 0.0897
# Epoch 17/1000 - Loss: 42.0358 - Val Accuracy: 0.0897
# Epoch 18/1000 - Loss: 42.0150 - Val Accuracy: 0.0897
# Epoch 19/1000 - Loss: 41.9938 - Val Accuracy: 0.0897
# Epoch 20/1000 - Loss: 41.9740 - Val Accuracy: 0.0897
# Epoch 21/1000 - Loss: 41.9547 - Val Accuracy: 0.0897
# Epoch 22/1000 - Loss: 41.9362 - Val Accuracy: 0.0897
# Epoch 23/1000 - Loss: 41.9180 - Val Accuracy: 0.0897
# Epoch 24/1000 - Loss: 41.9007 - Val Accuracy: 0.0897
# Epoch 25/1000 - Loss: 41.8840 - Val Accuracy: 0.0897
# Epoch 26/1000 - Loss: 41.8676 - Val Accuracy: 0.0897
# Epoch 27/1000 - Loss: 41.8522 - Val Accuracy: 0.0897
# Epoch 28/1000 - Loss: 41.8368 - Val Accuracy: 0.0897
# Epoch 29/1000 - Loss: 41.8220 - Val Accuracy: 0.0897
# Epoch 30/1000 - Loss: 41.8076 - Val Accuracy: 0.0897
# Epoch 31/1000 - Loss: 41.7943 - Val Accuracy: 0.0897
# Epoch 32/1000 - Loss: 41.7809 - Val Accuracy: 0.0897
# Epoch 33/1000 - Loss: 41.7679 - Val Accuracy: 0.0897
# Epoch 34/1000 - Loss: 41.7556 - Val Accuracy: 0.0897
# Epoch 35/1000 - Loss: 41.7434 - Val Accuracy: 0.0897
# Epoch 36/1000 - Loss: 41.7317 - Val Accuracy: 0.0897
# Epoch 37/1000 - Loss: 41.7205 - Val Accuracy: 0.0897
# Epoch 38/1000 - Loss: 41.7097 - Val Accuracy: 0.0897
# Epoch 39/1000 - Loss: 41.6991 - Val Accuracy: 0.0897
# Epoch 40/1000 - Loss: 41.6886 - Val Accuracy: 0.0897
# Epoch 41/1000 - Loss: 41.6787 - Val Accuracy: 0.0897
# Epoch 42/1000 - Loss: 41.6685 - Val Accuracy: 0.0897
# Epoch 43/1000 - Loss: 41.6593 - Val Accuracy: 0.0897
# Epoch 44/1000 - Loss: 41.6499 - Val Accuracy: 0.0897
# Epoch 45/1000 - Loss: 41.6409 - Val Accuracy: 0.0897
# Epoch 46/1000 - Loss: 41.6323 - Val Accuracy: 0.0897
# Epoch 47/1000 - Loss: 41.6234 - Val Accuracy: 0.0897
# Epoch 48/1000 - Loss: 41.6152 - Val Accuracy: 0.0897
# Epoch 49/1000 - Loss: 41.6072 - Val Accuracy: 0.0897
# Epoch 50/1000 - Loss: 41.5998 - Val Accuracy: 0.0897
# Epoch 51/1000 - Loss: 41.5919 - Val Accuracy: 0.0897
# Epoch 52/1000 - Loss: 41.5848 - Val Accuracy: 0.0897
# Epoch 53/1000 - Loss: 41.5781 - Val Accuracy: 0.0897
# Epoch 54/1000 - Loss: 41.5710 - Val Accuracy: 0.0897
# Epoch 55/1000 - Loss: 41.5640 - Val Accuracy: 0.0897
# Epoch 56/1000 - Loss: 41.5571 - Val Accuracy: 0.0897
# Epoch 57/1000 - Loss: 41.5510 - Val Accuracy: 0.0897
# Epoch 58/1000 - Loss: 41.5441 - Val Accuracy: 0.0897
# Epoch 59/1000 - Loss: 41.5380 - Val Accuracy: 0.0897
# Epoch 60/1000 - Loss: 41.5313 - Val Accuracy: 0.0897
# Epoch 61/1000 - Loss: 41.5254 - Val Accuracy: 0.0897
# Epoch 62/1000 - Loss: 41.5193 - Val Accuracy: 0.0897
# Epoch 63/1000 - Loss: 41.5131 - Val Accuracy: 0.0897
# Epoch 64/1000 - Loss: 41.5076 - Val Accuracy: 0.0897
# Epoch 65/1000 - Loss: 41.5014 - Val Accuracy: 0.0897
# Epoch 66/1000 - Loss: 41.4960 - Val Accuracy: 0.0916
# Epoch 67/1000 - Loss: 41.4911 - Val Accuracy: 0.0935
# Epoch 68/1000 - Loss: 41.4858 - Val Accuracy: 0.0954
# Epoch 69/1000 - Loss: 41.4806 - Val Accuracy: 0.0954
# Epoch 70/1000 - Loss: 41.4754 - Val Accuracy: 0.0954
# Epoch 71/1000 - Loss: 41.4709 - Val Accuracy: 0.0954
# Epoch 72/1000 - Loss: 41.4657 - Val Accuracy: 0.0973
# Epoch 73/1000 - Loss: 41.4616 - Val Accuracy: 0.0973
# Epoch 74/1000 - Loss: 41.4567 - Val Accuracy: 0.0973
# Epoch 75/1000 - Loss: 41.4527 - Val Accuracy: 0.0992
# Epoch 76/1000 - Loss: 41.4484 - Val Accuracy: 0.0992
# Epoch 77/1000 - Loss: 41.4438 - Val Accuracy: 0.1011
# Epoch 78/1000 - Loss: 41.4401 - Val Accuracy: 0.1050
# Epoch 79/1000 - Loss: 41.4360 - Val Accuracy: 0.1050
# Epoch 80/1000 - Loss: 41.4321 - Val Accuracy: 0.1050
# Epoch 81/1000 - Loss: 41.4281 - Val Accuracy: 0.1050
# Epoch 82/1000 - Loss: 41.4243 - Val Accuracy: 0.1050
# Epoch 83/1000 - Loss: 41.4208 - Val Accuracy: 0.1088
# Epoch 84/1000 - Loss: 41.4173 - Val Accuracy: 0.1145
# Epoch 85/1000 - Loss: 41.4136 - Val Accuracy: 0.1145
# Epoch 86/1000 - Loss: 41.4098 - Val Accuracy: 0.1164
# Epoch 87/1000 - Loss: 41.4067 - Val Accuracy: 0.1107
# Epoch 88/1000 - Loss: 41.4030 - Val Accuracy: 0.0973
# Epoch 89/1000 - Loss: 41.4001 - Val Accuracy: 0.0821
# Epoch 90/1000 - Loss: 41.3970 - Val Accuracy: 0.0802
# Epoch 91/1000 - Loss: 41.3936 - Val Accuracy: 0.0782
# Epoch 92/1000 - Loss: 41.3906 - Val Accuracy: 0.0802
# Epoch 93/1000 - Loss: 41.3875 - Val Accuracy: 0.0802
# Epoch 94/1000 - Loss: 41.3842 - Val Accuracy: 0.0782
# Epoch 95/1000 - Loss: 41.3813 - Val Accuracy: 0.0763
# Epoch 96/1000 - Loss: 41.3780 - Val Accuracy: 0.0782
# Epoch 97/1000 - Loss: 41.3758 - Val Accuracy: 0.0782
# Epoch 98/1000 - Loss: 41.3727 - Val Accuracy: 0.0782
# Epoch 99/1000 - Loss: 41.3697 - Val Accuracy: 0.0744
# Epoch 100/1000 - Loss: 41.3673 - Val Accuracy: 0.0744
# Epoch 101/1000 - Loss: 41.3641 - Val Accuracy: 0.0802
# Epoch 102/1000 - Loss: 41.3614 - Val Accuracy: 0.0802
# Epoch 103/1000 - Loss: 41.3590 - Val Accuracy: 0.0821
# Epoch 104/1000 - Loss: 41.3564 - Val Accuracy: 0.0821
# Epoch 105/1000 - Loss: 41.3533 - Val Accuracy: 0.0916
# Epoch 106/1000 - Loss: 41.3506 - Val Accuracy: 0.0935
# Epoch 107/1000 - Loss: 41.3483 - Val Accuracy: 0.0916
# Epoch 108/1000 - Loss: 41.3457 - Val Accuracy: 0.0973
# Epoch 109/1000 - Loss: 41.3431 - Val Accuracy: 0.0973
# Epoch 110/1000 - Loss: 41.3409 - Val Accuracy: 0.0992
# Epoch 111/1000 - Loss: 41.3381 - Val Accuracy: 0.0954
# Epoch 112/1000 - Loss: 41.3359 - Val Accuracy: 0.0954
# Epoch 113/1000 - Loss: 41.3333 - Val Accuracy: 0.0992
# Epoch 114/1000 - Loss: 41.3312 - Val Accuracy: 0.0992
# Epoch 115/1000 - Loss: 41.3281 - Val Accuracy: 0.0973
# Epoch 116/1000 - Loss: 41.3255 - Val Accuracy: 0.0973
# Epoch 117/1000 - Loss: 41.3231 - Val Accuracy: 0.0973
# Epoch 118/1000 - Loss: 41.3209 - Val Accuracy: 0.0973
# Epoch 119/1000 - Loss: 41.3182 - Val Accuracy: 0.0973
# Epoch 120/1000 - Loss: 41.3159 - Val Accuracy: 0.0973
# Epoch 121/1000 - Loss: 41.3134 - Val Accuracy: 0.0973
# Epoch 122/1000 - Loss: 41.3117 - Val Accuracy: 0.0973
# Epoch 123/1000 - Loss: 41.3091 - Val Accuracy: 0.0973
# Epoch 124/1000 - Loss: 41.3064 - Val Accuracy: 0.0973
# Epoch 125/1000 - Loss: 41.3041 - Val Accuracy: 0.0973
# Epoch 126/1000 - Loss: 41.3016 - Val Accuracy: 0.0973
# Epoch 127/1000 - Loss: 41.2993 - Val Accuracy: 0.0973
# Epoch 128/1000 - Loss: 41.2972 - Val Accuracy: 0.0973
# Epoch 129/1000 - Loss: 41.2948 - Val Accuracy: 0.0973
# Epoch 130/1000 - Loss: 41.2924 - Val Accuracy: 0.0973
# Epoch 131/1000 - Loss: 41.2901 - Val Accuracy: 0.0973
# Epoch 132/1000 - Loss: 41.2881 - Val Accuracy: 0.0973
# Epoch 133/1000 - Loss: 41.2854 - Val Accuracy: 0.0973
# Epoch 134/1000 - Loss: 41.2828 - Val Accuracy: 0.0973
# Epoch 135/1000 - Loss: 41.2808 - Val Accuracy: 0.0973
# Epoch 136/1000 - Loss: 41.2781 - Val Accuracy: 0.0973
# Epoch 137/1000 - Loss: 41.2756 - Val Accuracy: 0.0973
# Epoch 138/1000 - Loss: 41.2732 - Val Accuracy: 0.0973
# Epoch 139/1000 - Loss: 41.2711 - Val Accuracy: 0.0973
# Epoch 140/1000 - Loss: 41.2688 - Val Accuracy: 0.0973
# Epoch 141/1000 - Loss: 41.2665 - Val Accuracy: 0.0973
# Epoch 142/1000 - Loss: 41.2638 - Val Accuracy: 0.0973
# Epoch 143/1000 - Loss: 41.2618 - Val Accuracy: 0.0973
# Epoch 144/1000 - Loss: 41.2590 - Val Accuracy: 0.0973
# Epoch 145/1000 - Loss: 41.2568 - Val Accuracy: 0.0973
# Epoch 146/1000 - Loss: 41.2541 - Val Accuracy: 0.0973
# Epoch 147/1000 - Loss: 41.2516 - Val Accuracy: 0.0973
# Epoch 148/1000 - Loss: 41.2493 - Val Accuracy: 0.0973
# Epoch 149/1000 - Loss: 41.2469 - Val Accuracy: 0.0973
# Epoch 150/1000 - Loss: 41.2445 - Val Accuracy: 0.0973
# Epoch 151/1000 - Loss: 41.2421 - Val Accuracy: 0.0992
# Epoch 152/1000 - Loss: 41.2398 - Val Accuracy: 0.1011
# Epoch 153/1000 - Loss: 41.2368 - Val Accuracy: 0.1011
# Epoch 154/1000 - Loss: 41.2346 - Val Accuracy: 0.1011
# Epoch 155/1000 - Loss: 41.2318 - Val Accuracy: 0.1031
# Epoch 156/1000 - Loss: 41.2291 - Val Accuracy: 0.1031
# Epoch 157/1000 - Loss: 41.2266 - Val Accuracy: 0.1031
# Epoch 158/1000 - Loss: 41.2243 - Val Accuracy: 0.1031
# Epoch 159/1000 - Loss: 41.2216 - Val Accuracy: 0.1031
# Epoch 160/1000 - Loss: 41.2189 - Val Accuracy: 0.1069
# Epoch 161/1000 - Loss: 41.2165 - Val Accuracy: 0.1088
# Epoch 162/1000 - Loss: 41.2139 - Val Accuracy: 0.1107
# Epoch 163/1000 - Loss: 41.2107 - Val Accuracy: 0.1126
# Epoch 164/1000 - Loss: 41.2083 - Val Accuracy: 0.1145
# Epoch 165/1000 - Loss: 41.2056 - Val Accuracy: 0.1145
# Epoch 166/1000 - Loss: 41.2029 - Val Accuracy: 0.1145
# Epoch 167/1000 - Loss: 41.2003 - Val Accuracy: 0.1164
# Epoch 168/1000 - Loss: 41.1973 - Val Accuracy: 0.1183
# Epoch 169/1000 - Loss: 41.1945 - Val Accuracy: 0.1221
# Epoch 170/1000 - Loss: 41.1917 - Val Accuracy: 0.1298
# Epoch 171/1000 - Loss: 41.1895 - Val Accuracy: 0.1412
# Epoch 172/1000 - Loss: 41.1864 - Val Accuracy: 0.1469
# Epoch 173/1000 - Loss: 41.1836 - Val Accuracy: 0.1489
# Epoch 174/1000 - Loss: 41.1808 - Val Accuracy: 0.1527
# Epoch 175/1000 - Loss: 41.1780 - Val Accuracy: 0.1527
# Epoch 176/1000 - Loss: 41.1754 - Val Accuracy: 0.1584
# Epoch 177/1000 - Loss: 41.1722 - Val Accuracy: 0.1660
# Epoch 178/1000 - Loss: 41.1692 - Val Accuracy: 0.1718
# Epoch 179/1000 - Loss: 41.1666 - Val Accuracy: 0.1737
# Epoch 180/1000 - Loss: 41.1637 - Val Accuracy: 0.1756
# Epoch 181/1000 - Loss: 41.1607 - Val Accuracy: 0.1756
# Epoch 182/1000 - Loss: 41.1577 - Val Accuracy: 0.1756
# Epoch 183/1000 - Loss: 41.1546 - Val Accuracy: 0.1756
# Epoch 184/1000 - Loss: 41.1515 - Val Accuracy: 0.1756
# Epoch 185/1000 - Loss: 41.1485 - Val Accuracy: 0.1775
# Epoch 186/1000 - Loss: 41.1455 - Val Accuracy: 0.1775
# Epoch 187/1000 - Loss: 41.1424 - Val Accuracy: 0.1794
# Epoch 188/1000 - Loss: 41.1393 - Val Accuracy: 0.1794
# Epoch 189/1000 - Loss: 41.1362 - Val Accuracy: 0.1832
# Epoch 190/1000 - Loss: 41.1328 - Val Accuracy: 0.1851
# Epoch 191/1000 - Loss: 41.1298 - Val Accuracy: 0.1851
# Epoch 192/1000 - Loss: 41.1264 - Val Accuracy: 0.1870
# Epoch 193/1000 - Loss: 41.1233 - Val Accuracy: 0.1889
# Epoch 194/1000 - Loss: 41.1199 - Val Accuracy: 0.1889
# Epoch 195/1000 - Loss: 41.1168 - Val Accuracy: 0.1889
# Epoch 196/1000 - Loss: 41.1131 - Val Accuracy: 0.1947
# Epoch 197/1000 - Loss: 41.1101 - Val Accuracy: 0.1947
# Epoch 198/1000 - Loss: 41.1068 - Val Accuracy: 0.1966
# Epoch 199/1000 - Loss: 41.1031 - Val Accuracy: 0.1985
# Epoch 200/1000 - Loss: 41.0998 - Val Accuracy: 0.2042
# Epoch 201/1000 - Loss: 41.0964 - Val Accuracy: 0.2061
# Epoch 202/1000 - Loss: 41.0924 - Val Accuracy: 0.2061
# Epoch 203/1000 - Loss: 41.0897 - Val Accuracy: 0.2080
# Epoch 204/1000 - Loss: 41.0856 - Val Accuracy: 0.2156
# Epoch 205/1000 - Loss: 41.0826 - Val Accuracy: 0.2252
# Epoch 206/1000 - Loss: 41.0787 - Val Accuracy: 0.2328
# Epoch 207/1000 - Loss: 41.0749 - Val Accuracy: 0.2347
# Epoch 208/1000 - Loss: 41.0713 - Val Accuracy: 0.2385
# Epoch 209/1000 - Loss: 41.0675 - Val Accuracy: 0.2424
# Epoch 210/1000 - Loss: 41.0642 - Val Accuracy: 0.2462
# Epoch 211/1000 - Loss: 41.0602 - Val Accuracy: 0.2481
# Epoch 212/1000 - Loss: 41.0563 - Val Accuracy: 0.2519
# Epoch 213/1000 - Loss: 41.0521 - Val Accuracy: 0.2538
# Epoch 214/1000 - Loss: 41.0486 - Val Accuracy: 0.2538
# Epoch 215/1000 - Loss: 41.0446 - Val Accuracy: 0.2538
# Epoch 216/1000 - Loss: 41.0409 - Val Accuracy: 0.2557
# Epoch 217/1000 - Loss: 41.0365 - Val Accuracy: 0.2595
# Epoch 218/1000 - Loss: 41.0328 - Val Accuracy: 0.2653
# Epoch 219/1000 - Loss: 41.0290 - Val Accuracy: 0.2710
# Epoch 220/1000 - Loss: 41.0246 - Val Accuracy: 0.2729
# Epoch 221/1000 - Loss: 41.0206 - Val Accuracy: 0.2767
# Epoch 222/1000 - Loss: 41.0162 - Val Accuracy: 0.2786
# Epoch 223/1000 - Loss: 41.0119 - Val Accuracy: 0.2786
# Epoch 224/1000 - Loss: 41.0080 - Val Accuracy: 0.2805
# Epoch 225/1000 - Loss: 41.0035 - Val Accuracy: 0.2786
# Epoch 226/1000 - Loss: 40.9990 - Val Accuracy: 0.2844
# Epoch 227/1000 - Loss: 40.9947 - Val Accuracy: 0.2863
# Epoch 228/1000 - Loss: 40.9893 - Val Accuracy: 0.2844
# Epoch 229/1000 - Loss: 40.9839 - Val Accuracy: 0.2824
# Epoch 230/1000 - Loss: 40.9788 - Val Accuracy: 0.2824
# Epoch 231/1000 - Loss: 40.9737 - Val Accuracy: 0.2824
# Epoch 232/1000 - Loss: 40.9683 - Val Accuracy: 0.2824
# Epoch 233/1000 - Loss: 40.9628 - Val Accuracy: 0.2805
# Epoch 234/1000 - Loss: 40.9570 - Val Accuracy: 0.2824
# Epoch 235/1000 - Loss: 40.9507 - Val Accuracy: 0.2805
# Epoch 236/1000 - Loss: 40.9448 - Val Accuracy: 0.2786
# Epoch 237/1000 - Loss: 40.9383 - Val Accuracy: 0.2786
# Epoch 238/1000 - Loss: 40.9317 - Val Accuracy: 0.2786
# Epoch 239/1000 - Loss: 40.9252 - Val Accuracy: 0.2786
# Epoch 240/1000 - Loss: 40.9188 - Val Accuracy: 0.2786
# Epoch 241/1000 - Loss: 40.9112 - Val Accuracy: 0.2805
# Epoch 242/1000 - Loss: 40.9039 - Val Accuracy: 0.2805
# Epoch 243/1000 - Loss: 40.8962 - Val Accuracy: 0.2767
# Epoch 244/1000 - Loss: 40.8884 - Val Accuracy: 0.2748
# Epoch 245/1000 - Loss: 40.8802 - Val Accuracy: 0.2748
# Epoch 246/1000 - Loss: 40.8714 - Val Accuracy: 0.2691
# Epoch 247/1000 - Loss: 40.8629 - Val Accuracy: 0.2691
# Epoch 248/1000 - Loss: 40.8541 - Val Accuracy: 0.2691
# Epoch 249/1000 - Loss: 40.8447 - Val Accuracy: 0.2691
# Epoch 250/1000 - Loss: 40.8354 - Val Accuracy: 0.2672
# Epoch 251/1000 - Loss: 40.8270 - Val Accuracy: 0.2691
# Epoch 252/1000 - Loss: 40.8173 - Val Accuracy: 0.2691
# Epoch 253/1000 - Loss: 40.8083 - Val Accuracy: 0.2672
# Epoch 254/1000 - Loss: 40.7991 - Val Accuracy: 0.2672
# Epoch 255/1000 - Loss: 40.7899 - Val Accuracy: 0.2672
# Epoch 256/1000 - Loss: 40.7810 - Val Accuracy: 0.2691
# Epoch 257/1000 - Loss: 40.7716 - Val Accuracy: 0.2710
# Epoch 258/1000 - Loss: 40.7617 - Val Accuracy: 0.2691
# Epoch 259/1000 - Loss: 40.7523 - Val Accuracy: 0.2691
# Epoch 260/1000 - Loss: 40.7429 - Val Accuracy: 0.2691
# Epoch 261/1000 - Loss: 40.7336 - Val Accuracy: 0.2691
# Epoch 262/1000 - Loss: 40.7237 - Val Accuracy: 0.2691
# Epoch 263/1000 - Loss: 40.7140 - Val Accuracy: 0.2672
# Epoch 264/1000 - Loss: 40.7049 - Val Accuracy: 0.2672
# Epoch 265/1000 - Loss: 40.6942 - Val Accuracy: 0.2653
# Epoch 266/1000 - Loss: 40.6841 - Val Accuracy: 0.2691
# Epoch 267/1000 - Loss: 40.6742 - Val Accuracy: 0.2672
# Epoch 268/1000 - Loss: 40.6642 - Val Accuracy: 0.2710
# Epoch 269/1000 - Loss: 40.6543 - Val Accuracy: 0.2710
# Epoch 270/1000 - Loss: 40.6447 - Val Accuracy: 0.2710
# Epoch 271/1000 - Loss: 40.6341 - Val Accuracy: 0.2710
# Epoch 272/1000 - Loss: 40.6235 - Val Accuracy: 0.2691
# Epoch 273/1000 - Loss: 40.6124 - Val Accuracy: 0.2729
# Epoch 274/1000 - Loss: 40.6023 - Val Accuracy: 0.2729
# Epoch 275/1000 - Loss: 40.5917 - Val Accuracy: 0.2729
# Epoch 276/1000 - Loss: 40.5810 - Val Accuracy: 0.2748
# Epoch 277/1000 - Loss: 40.5702 - Val Accuracy: 0.2805
# Epoch 278/1000 - Loss: 40.5597 - Val Accuracy: 0.2786
# Epoch 279/1000 - Loss: 40.5486 - Val Accuracy: 0.2786
# Epoch 280/1000 - Loss: 40.5375 - Val Accuracy: 0.2863
# Epoch 281/1000 - Loss: 40.5272 - Val Accuracy: 0.2844
# Epoch 282/1000 - Loss: 40.5148 - Val Accuracy: 0.2824
# Epoch 283/1000 - Loss: 40.5036 - Val Accuracy: 0.2824
# Epoch 284/1000 - Loss: 40.4924 - Val Accuracy: 0.2786
# Epoch 285/1000 - Loss: 40.4809 - Val Accuracy: 0.2824
# Epoch 286/1000 - Loss: 40.4694 - Val Accuracy: 0.2824
# Epoch 287/1000 - Loss: 40.4576 - Val Accuracy: 0.2824
# Epoch 288/1000 - Loss: 40.4463 - Val Accuracy: 0.2824
# Epoch 289/1000 - Loss: 40.4340 - Val Accuracy: 0.2844
# Epoch 290/1000 - Loss: 40.4217 - Val Accuracy: 0.2863
# Epoch 291/1000 - Loss: 40.4099 - Val Accuracy: 0.2901
# Epoch 292/1000 - Loss: 40.3980 - Val Accuracy: 0.2901
# Epoch 293/1000 - Loss: 40.3853 - Val Accuracy: 0.2901
# Epoch 294/1000 - Loss: 40.3734 - Val Accuracy: 0.2901
# Epoch 295/1000 - Loss: 40.3605 - Val Accuracy: 0.2920
# Epoch 296/1000 - Loss: 40.3479 - Val Accuracy: 0.2920
# Epoch 297/1000 - Loss: 40.3356 - Val Accuracy: 0.2920
# Epoch 298/1000 - Loss: 40.3223 - Val Accuracy: 0.2920
# Epoch 299/1000 - Loss: 40.3094 - Val Accuracy: 0.2939
# Epoch 300/1000 - Loss: 40.2968 - Val Accuracy: 0.2958
# Epoch 301/1000 - Loss: 40.2832 - Val Accuracy: 0.2958
# Epoch 302/1000 - Loss: 40.2702 - Val Accuracy: 0.2996
# Epoch 303/1000 - Loss: 40.2564 - Val Accuracy: 0.2977
# Epoch 304/1000 - Loss: 40.2426 - Val Accuracy: 0.2996
# Epoch 305/1000 - Loss: 40.2298 - Val Accuracy: 0.3015
# Epoch 306/1000 - Loss: 40.2160 - Val Accuracy: 0.3015
# Epoch 307/1000 - Loss: 40.2015 - Val Accuracy: 0.2996
# Epoch 308/1000 - Loss: 40.1880 - Val Accuracy: 0.3015
# Epoch 309/1000 - Loss: 40.1738 - Val Accuracy: 0.3053
# Epoch 310/1000 - Loss: 40.1594 - Val Accuracy: 0.3015
# Epoch 311/1000 - Loss: 40.1454 - Val Accuracy: 0.3053
# Epoch 312/1000 - Loss: 40.1308 - Val Accuracy: 0.3053
# Epoch 313/1000 - Loss: 40.1155 - Val Accuracy: 0.3053
# Epoch 314/1000 - Loss: 40.1012 - Val Accuracy: 0.3092
# Epoch 315/1000 - Loss: 40.0858 - Val Accuracy: 0.3092
# Epoch 316/1000 - Loss: 40.0713 - Val Accuracy: 0.3092
# Epoch 317/1000 - Loss: 40.0560 - Val Accuracy: 0.3130
# Epoch 318/1000 - Loss: 40.0409 - Val Accuracy: 0.3130
# Epoch 319/1000 - Loss: 40.0248 - Val Accuracy: 0.3130
# Epoch 320/1000 - Loss: 40.0093 - Val Accuracy: 0.3111
# Epoch 321/1000 - Loss: 39.9937 - Val Accuracy: 0.3111
# Epoch 322/1000 - Loss: 39.9783 - Val Accuracy: 0.3111
# Epoch 323/1000 - Loss: 39.9623 - Val Accuracy: 0.3111
# Epoch 324/1000 - Loss: 39.9464 - Val Accuracy: 0.3130
# Epoch 325/1000 - Loss: 39.9301 - Val Accuracy: 0.3149
# Epoch 326/1000 - Loss: 39.9126 - Val Accuracy: 0.3168
# Epoch 327/1000 - Loss: 39.8960 - Val Accuracy: 0.3168
# Epoch 328/1000 - Loss: 39.8795 - Val Accuracy: 0.3168
# Epoch 329/1000 - Loss: 39.8623 - Val Accuracy: 0.3168
# Epoch 330/1000 - Loss: 39.8456 - Val Accuracy: 0.3168
# Epoch 331/1000 - Loss: 39.8287 - Val Accuracy: 0.3149
# Epoch 332/1000 - Loss: 39.8109 - Val Accuracy: 0.3225
# Epoch 333/1000 - Loss: 39.7934 - Val Accuracy: 0.3244
# Epoch 334/1000 - Loss: 39.7759 - Val Accuracy: 0.3282
# Epoch 335/1000 - Loss: 39.7576 - Val Accuracy: 0.3282
# Epoch 336/1000 - Loss: 39.7395 - Val Accuracy: 0.3263
# Epoch 337/1000 - Loss: 39.7217 - Val Accuracy: 0.3302
# Epoch 338/1000 - Loss: 39.7030 - Val Accuracy: 0.3302
# Epoch 339/1000 - Loss: 39.6842 - Val Accuracy: 0.3340
# Epoch 340/1000 - Loss: 39.6653 - Val Accuracy: 0.3378
# Epoch 341/1000 - Loss: 39.6473 - Val Accuracy: 0.3359
# Epoch 342/1000 - Loss: 39.6283 - Val Accuracy: 0.3359
# Epoch 343/1000 - Loss: 39.6084 - Val Accuracy: 0.3378
# Epoch 344/1000 - Loss: 39.5897 - Val Accuracy: 0.3378
# Epoch 345/1000 - Loss: 39.5694 - Val Accuracy: 0.3397
# Epoch 346/1000 - Loss: 39.5504 - Val Accuracy: 0.3378
# Epoch 347/1000 - Loss: 39.5305 - Val Accuracy: 0.3435
# Epoch 348/1000 - Loss: 39.5100 - Val Accuracy: 0.3454
# Epoch 349/1000 - Loss: 39.4901 - Val Accuracy: 0.3454
# Epoch 350/1000 - Loss: 39.4691 - Val Accuracy: 0.3454
# Epoch 351/1000 - Loss: 39.4490 - Val Accuracy: 0.3454
# Epoch 352/1000 - Loss: 39.4276 - Val Accuracy: 0.3454
# Epoch 353/1000 - Loss: 39.4066 - Val Accuracy: 0.3473
# Epoch 354/1000 - Loss: 39.3848 - Val Accuracy: 0.3511
# Epoch 355/1000 - Loss: 39.3640 - Val Accuracy: 0.3531
# Epoch 356/1000 - Loss: 39.3426 - Val Accuracy: 0.3531
# Epoch 357/1000 - Loss: 39.3212 - Val Accuracy: 0.3550
# Epoch 358/1000 - Loss: 39.2994 - Val Accuracy: 0.3550
# Epoch 359/1000 - Loss: 39.2766 - Val Accuracy: 0.3550
# Epoch 360/1000 - Loss: 39.2543 - Val Accuracy: 0.3607
# Epoch 361/1000 - Loss: 39.2328 - Val Accuracy: 0.3569
# Epoch 362/1000 - Loss: 39.2093 - Val Accuracy: 0.3550
# Epoch 363/1000 - Loss: 39.1868 - Val Accuracy: 0.3607
# Epoch 364/1000 - Loss: 39.1631 - Val Accuracy: 0.3607
# Epoch 365/1000 - Loss: 39.1398 - Val Accuracy: 0.3569
# Epoch 366/1000 - Loss: 39.1164 - Val Accuracy: 0.3626
# Epoch 367/1000 - Loss: 39.0922 - Val Accuracy: 0.3607
# Epoch 368/1000 - Loss: 39.0689 - Val Accuracy: 0.3626
# Epoch 369/1000 - Loss: 39.0450 - Val Accuracy: 0.3607
# Epoch 370/1000 - Loss: 39.0202 - Val Accuracy: 0.3607
# Epoch 371/1000 - Loss: 38.9956 - Val Accuracy: 0.3588
# Epoch 372/1000 - Loss: 38.9708 - Val Accuracy: 0.3588
# Epoch 373/1000 - Loss: 38.9454 - Val Accuracy: 0.3588
# Epoch 374/1000 - Loss: 38.9203 - Val Accuracy: 0.3645
# Epoch 375/1000 - Loss: 38.8961 - Val Accuracy: 0.3645
# Epoch 376/1000 - Loss: 38.8694 - Val Accuracy: 0.3664
# Epoch 377/1000 - Loss: 38.8441 - Val Accuracy: 0.3721
# Epoch 378/1000 - Loss: 38.8187 - Val Accuracy: 0.3683
# Epoch 379/1000 - Loss: 38.7918 - Val Accuracy: 0.3664
# Epoch 380/1000 - Loss: 38.7659 - Val Accuracy: 0.3664
# Epoch 381/1000 - Loss: 38.7388 - Val Accuracy: 0.3721
# Epoch 382/1000 - Loss: 38.7118 - Val Accuracy: 0.3721
# Epoch 383/1000 - Loss: 38.6844 - Val Accuracy: 0.3760
# Epoch 384/1000 - Loss: 38.6575 - Val Accuracy: 0.3779
# Epoch 385/1000 - Loss: 38.6297 - Val Accuracy: 0.3760
# Epoch 386/1000 - Loss: 38.6030 - Val Accuracy: 0.3740
# Epoch 387/1000 - Loss: 38.5746 - Val Accuracy: 0.3760
# Epoch 388/1000 - Loss: 38.5456 - Val Accuracy: 0.3760
# Epoch 389/1000 - Loss: 38.5174 - Val Accuracy: 0.3798
# Epoch 390/1000 - Loss: 38.4885 - Val Accuracy: 0.3798
# Epoch 391/1000 - Loss: 38.4605 - Val Accuracy: 0.3779
# Epoch 392/1000 - Loss: 38.4308 - Val Accuracy: 0.3817
# Epoch 393/1000 - Loss: 38.4015 - Val Accuracy: 0.3817
# Epoch 394/1000 - Loss: 38.3728 - Val Accuracy: 0.3836
# Epoch 395/1000 - Loss: 38.3430 - Val Accuracy: 0.3836
# Epoch 396/1000 - Loss: 38.3115 - Val Accuracy: 0.3855
# Epoch 397/1000 - Loss: 38.2828 - Val Accuracy: 0.3855
# Epoch 398/1000 - Loss: 38.2516 - Val Accuracy: 0.3855
# Epoch 399/1000 - Loss: 38.2215 - Val Accuracy: 0.3855
# Epoch 400/1000 - Loss: 38.1908 - Val Accuracy: 0.3874
# Epoch 401/1000 - Loss: 38.1587 - Val Accuracy: 0.3874
# Epoch 402/1000 - Loss: 38.1280 - Val Accuracy: 0.3874
# Epoch 403/1000 - Loss: 38.0971 - Val Accuracy: 0.3893
# Epoch 404/1000 - Loss: 38.0638 - Val Accuracy: 0.3874
# Epoch 405/1000 - Loss: 38.0324 - Val Accuracy: 0.3950
# Epoch 406/1000 - Loss: 37.9998 - Val Accuracy: 0.3950
# Epoch 407/1000 - Loss: 37.9683 - Val Accuracy: 0.4027
# Epoch 408/1000 - Loss: 37.9351 - Val Accuracy: 0.4046
# Epoch 409/1000 - Loss: 37.9023 - Val Accuracy: 0.4084
# Epoch 410/1000 - Loss: 37.8698 - Val Accuracy: 0.4046
# Epoch 411/1000 - Loss: 37.8356 - Val Accuracy: 0.4103
# Epoch 412/1000 - Loss: 37.8028 - Val Accuracy: 0.4103
# Epoch 413/1000 - Loss: 37.7693 - Val Accuracy: 0.4141
# Epoch 414/1000 - Loss: 37.7348 - Val Accuracy: 0.4122
# Epoch 415/1000 - Loss: 37.6999 - Val Accuracy: 0.4179
# Epoch 416/1000 - Loss: 37.6661 - Val Accuracy: 0.4198
# Epoch 417/1000 - Loss: 37.6315 - Val Accuracy: 0.4218
# Epoch 418/1000 - Loss: 37.5964 - Val Accuracy: 0.4198
# Epoch 419/1000 - Loss: 37.5622 - Val Accuracy: 0.4218
# Epoch 420/1000 - Loss: 37.5251 - Val Accuracy: 0.4237
# Epoch 421/1000 - Loss: 37.4902 - Val Accuracy: 0.4256
# Epoch 422/1000 - Loss: 37.4548 - Val Accuracy: 0.4256
# Epoch 423/1000 - Loss: 37.4174 - Val Accuracy: 0.4275
# Epoch 424/1000 - Loss: 37.3817 - Val Accuracy: 0.4275
# Epoch 425/1000 - Loss: 37.3451 - Val Accuracy: 0.4275
# Epoch 426/1000 - Loss: 37.3079 - Val Accuracy: 0.4275
# Epoch 427/1000 - Loss: 37.2717 - Val Accuracy: 0.4351
# Epoch 428/1000 - Loss: 37.2349 - Val Accuracy: 0.4370
# Epoch 429/1000 - Loss: 37.1976 - Val Accuracy: 0.4389
# Epoch 430/1000 - Loss: 37.1595 - Val Accuracy: 0.4408
# Epoch 431/1000 - Loss: 37.1224 - Val Accuracy: 0.4408
# Epoch 432/1000 - Loss: 37.0830 - Val Accuracy: 0.4427
# Epoch 433/1000 - Loss: 37.0457 - Val Accuracy: 0.4408
# Epoch 434/1000 - Loss: 37.0068 - Val Accuracy: 0.4447
# Epoch 435/1000 - Loss: 36.9682 - Val Accuracy: 0.4447
# Epoch 436/1000 - Loss: 36.9291 - Val Accuracy: 0.4447
# Epoch 437/1000 - Loss: 36.8900 - Val Accuracy: 0.4466
# Epoch 438/1000 - Loss: 36.8521 - Val Accuracy: 0.4485
# Epoch 439/1000 - Loss: 36.8124 - Val Accuracy: 0.4504
# Epoch 440/1000 - Loss: 36.7723 - Val Accuracy: 0.4504
# Epoch 441/1000 - Loss: 36.7315 - Val Accuracy: 0.4523
# Epoch 442/1000 - Loss: 36.6910 - Val Accuracy: 0.4523
# Epoch 443/1000 - Loss: 36.6516 - Val Accuracy: 0.4542
# Epoch 444/1000 - Loss: 36.6116 - Val Accuracy: 0.4542
# Epoch 445/1000 - Loss: 36.5710 - Val Accuracy: 0.4580
# Epoch 446/1000 - Loss: 36.5289 - Val Accuracy: 0.4580
# Epoch 447/1000 - Loss: 36.4877 - Val Accuracy: 0.4599
# Epoch 448/1000 - Loss: 36.4475 - Val Accuracy: 0.4599
# Epoch 449/1000 - Loss: 36.4050 - Val Accuracy: 0.4637
# Epoch 450/1000 - Loss: 36.3641 - Val Accuracy: 0.4676
# Epoch 451/1000 - Loss: 36.3227 - Val Accuracy: 0.4676
# Epoch 452/1000 - Loss: 36.2796 - Val Accuracy: 0.4676
# Epoch 453/1000 - Loss: 36.2376 - Val Accuracy: 0.4656
# Epoch 454/1000 - Loss: 36.1954 - Val Accuracy: 0.4637
# Epoch 455/1000 - Loss: 36.1533 - Val Accuracy: 0.4656
# Epoch 456/1000 - Loss: 36.1110 - Val Accuracy: 0.4637
# Epoch 457/1000 - Loss: 36.0655 - Val Accuracy: 0.4637
# Epoch 458/1000 - Loss: 36.0247 - Val Accuracy: 0.4637
# Epoch 459/1000 - Loss: 35.9805 - Val Accuracy: 0.4637
# Epoch 460/1000 - Loss: 35.9381 - Val Accuracy: 0.4656
# Epoch 461/1000 - Loss: 35.8947 - Val Accuracy: 0.4676
# Epoch 462/1000 - Loss: 35.8500 - Val Accuracy: 0.4695
# Epoch 463/1000 - Loss: 35.8058 - Val Accuracy: 0.4714
# Epoch 464/1000 - Loss: 35.7626 - Val Accuracy: 0.4752
# Epoch 465/1000 - Loss: 35.7177 - Val Accuracy: 0.4733
# Epoch 466/1000 - Loss: 35.6736 - Val Accuracy: 0.4714
# Epoch 467/1000 - Loss: 35.6293 - Val Accuracy: 0.4752
# Epoch 468/1000 - Loss: 35.5839 - Val Accuracy: 0.4771
# Epoch 469/1000 - Loss: 35.5387 - Val Accuracy: 0.4752
# Epoch 470/1000 - Loss: 35.4943 - Val Accuracy: 0.4790
# Epoch 471/1000 - Loss: 35.4497 - Val Accuracy: 0.4771
# Epoch 472/1000 - Loss: 35.4033 - Val Accuracy: 0.4809
# Epoch 473/1000 - Loss: 35.3597 - Val Accuracy: 0.4847
# Epoch 474/1000 - Loss: 35.3125 - Val Accuracy: 0.4828
# Epoch 475/1000 - Loss: 35.2673 - Val Accuracy: 0.4828
# Epoch 476/1000 - Loss: 35.2214 - Val Accuracy: 0.4809
# Epoch 477/1000 - Loss: 35.1751 - Val Accuracy: 0.4828
# Epoch 478/1000 - Loss: 35.1288 - Val Accuracy: 0.4847
# Epoch 479/1000 - Loss: 35.0839 - Val Accuracy: 0.4847
# Epoch 480/1000 - Loss: 35.0360 - Val Accuracy: 0.4847
# Epoch 481/1000 - Loss: 34.9898 - Val Accuracy: 0.4828
# Epoch 482/1000 - Loss: 34.9446 - Val Accuracy: 0.4809
# Epoch 483/1000 - Loss: 34.8979 - Val Accuracy: 0.4866
# Epoch 484/1000 - Loss: 34.8495 - Val Accuracy: 0.4847
# Epoch 485/1000 - Loss: 34.8027 - Val Accuracy: 0.4847
# Epoch 486/1000 - Loss: 34.7555 - Val Accuracy: 0.4847
# Epoch 487/1000 - Loss: 34.7090 - Val Accuracy: 0.4866
# Epoch 488/1000 - Loss: 34.6638 - Val Accuracy: 0.4847
# Epoch 489/1000 - Loss: 34.6153 - Val Accuracy: 0.4828
# Epoch 490/1000 - Loss: 34.5689 - Val Accuracy: 0.4847
# Epoch 491/1000 - Loss: 34.5201 - Val Accuracy: 0.4847
# Epoch 492/1000 - Loss: 34.4741 - Val Accuracy: 0.4828
# Epoch 493/1000 - Loss: 34.4244 - Val Accuracy: 0.4828
# Epoch 494/1000 - Loss: 34.3772 - Val Accuracy: 0.4847
# Epoch 495/1000 - Loss: 34.3315 - Val Accuracy: 0.4847
# Epoch 496/1000 - Loss: 34.2820 - Val Accuracy: 0.4866
# Epoch 497/1000 - Loss: 34.2337 - Val Accuracy: 0.4866
# Epoch 498/1000 - Loss: 34.1853 - Val Accuracy: 0.4866
# Epoch 499/1000 - Loss: 34.1380 - Val Accuracy: 0.4905
# Epoch 500/1000 - Loss: 34.0903 - Val Accuracy: 0.4885
# Epoch 501/1000 - Loss: 34.0408 - Val Accuracy: 0.4924
# Epoch 502/1000 - Loss: 33.9933 - Val Accuracy: 0.4943
# Epoch 503/1000 - Loss: 33.9452 - Val Accuracy: 0.4943
# Epoch 504/1000 - Loss: 33.8961 - Val Accuracy: 0.4962
# Epoch 505/1000 - Loss: 33.8470 - Val Accuracy: 0.4962
# Epoch 506/1000 - Loss: 33.7998 - Val Accuracy: 0.4962
# Epoch 507/1000 - Loss: 33.7508 - Val Accuracy: 0.4962
# Epoch 508/1000 - Loss: 33.7031 - Val Accuracy: 0.4943
# Epoch 509/1000 - Loss: 33.6541 - Val Accuracy: 0.4962
# Epoch 510/1000 - Loss: 33.6051 - Val Accuracy: 0.4962
# Epoch 511/1000 - Loss: 33.5556 - Val Accuracy: 0.4962
# Epoch 512/1000 - Loss: 33.5075 - Val Accuracy: 0.4981
# Epoch 513/1000 - Loss: 33.4577 - Val Accuracy: 0.4981
# Epoch 514/1000 - Loss: 33.4086 - Val Accuracy: 0.5019
# Epoch 515/1000 - Loss: 33.3625 - Val Accuracy: 0.5000
# Epoch 516/1000 - Loss: 33.3108 - Val Accuracy: 0.5019
# Epoch 517/1000 - Loss: 33.2614 - Val Accuracy: 0.5019
# Epoch 518/1000 - Loss: 33.2128 - Val Accuracy: 0.5038
# Epoch 519/1000 - Loss: 33.1647 - Val Accuracy: 0.5038
# Epoch 520/1000 - Loss: 33.1152 - Val Accuracy: 0.5057
# Epoch 521/1000 - Loss: 33.0666 - Val Accuracy: 0.5057
# Epoch 522/1000 - Loss: 33.0169 - Val Accuracy: 0.5038
# Epoch 523/1000 - Loss: 32.9676 - Val Accuracy: 0.5038
# Epoch 524/1000 - Loss: 32.9182 - Val Accuracy: 0.5038
# Epoch 525/1000 - Loss: 32.8698 - Val Accuracy: 0.5057
# Epoch 526/1000 - Loss: 32.8215 - Val Accuracy: 0.5057
# Epoch 527/1000 - Loss: 32.7714 - Val Accuracy: 0.5000
# Epoch 528/1000 - Loss: 32.7233 - Val Accuracy: 0.5057
# Epoch 529/1000 - Loss: 32.6748 - Val Accuracy: 0.5019
# Epoch 530/1000 - Loss: 32.6240 - Val Accuracy: 0.5000
# Epoch 531/1000 - Loss: 32.5752 - Val Accuracy: 0.5057
# Epoch 532/1000 - Loss: 32.5247 - Val Accuracy: 0.5057
# Epoch 533/1000 - Loss: 32.4757 - Val Accuracy: 0.5057
# Epoch 534/1000 - Loss: 32.4276 - Val Accuracy: 0.5038
# Epoch 535/1000 - Loss: 32.3766 - Val Accuracy: 0.5057
# Epoch 536/1000 - Loss: 32.3286 - Val Accuracy: 0.5076
# Epoch 537/1000 - Loss: 32.2798 - Val Accuracy: 0.5076
# Epoch 538/1000 - Loss: 32.2303 - Val Accuracy: 0.5095
# Epoch 539/1000 - Loss: 32.1834 - Val Accuracy: 0.5076
# Epoch 540/1000 - Loss: 32.1333 - Val Accuracy: 0.5095
# Epoch 541/1000 - Loss: 32.0841 - Val Accuracy: 0.5115
# Epoch 542/1000 - Loss: 32.0353 - Val Accuracy: 0.5115
# Epoch 543/1000 - Loss: 31.9863 - Val Accuracy: 0.5095
# Epoch 544/1000 - Loss: 31.9379 - Val Accuracy: 0.5057
# Epoch 545/1000 - Loss: 31.8883 - Val Accuracy: 0.5115
# Epoch 546/1000 - Loss: 31.8388 - Val Accuracy: 0.5134
# Epoch 547/1000 - Loss: 31.7882 - Val Accuracy: 0.5134
# Epoch 548/1000 - Loss: 31.7425 - Val Accuracy: 0.5134
# Epoch 549/1000 - Loss: 31.6922 - Val Accuracy: 0.5153
# Epoch 550/1000 - Loss: 31.6438 - Val Accuracy: 0.5153
# Epoch 551/1000 - Loss: 31.5957 - Val Accuracy: 0.5134
# Epoch 552/1000 - Loss: 31.5474 - Val Accuracy: 0.5153
# Epoch 553/1000 - Loss: 31.4991 - Val Accuracy: 0.5153
# Epoch 554/1000 - Loss: 31.4483 - Val Accuracy: 0.5153
# Epoch 555/1000 - Loss: 31.3997 - Val Accuracy: 0.5153
# Epoch 556/1000 - Loss: 31.3523 - Val Accuracy: 0.5191
# Epoch 557/1000 - Loss: 31.3020 - Val Accuracy: 0.5172
# Epoch 558/1000 - Loss: 31.2542 - Val Accuracy: 0.5191
# Epoch 559/1000 - Loss: 31.2075 - Val Accuracy: 0.5172
# Epoch 560/1000 - Loss: 31.1579 - Val Accuracy: 0.5210
# Epoch 561/1000 - Loss: 31.1098 - Val Accuracy: 0.5229
# Epoch 562/1000 - Loss: 31.0613 - Val Accuracy: 0.5229
# Epoch 563/1000 - Loss: 31.0122 - Val Accuracy: 0.5248
# Epoch 564/1000 - Loss: 30.9653 - Val Accuracy: 0.5267
# Epoch 565/1000 - Loss: 30.9155 - Val Accuracy: 0.5229
# Epoch 566/1000 - Loss: 30.8679 - Val Accuracy: 0.5248
# Epoch 567/1000 - Loss: 30.8203 - Val Accuracy: 0.5248
# Epoch 568/1000 - Loss: 30.7731 - Val Accuracy: 0.5305
# Epoch 569/1000 - Loss: 30.7245 - Val Accuracy: 0.5305
# Epoch 570/1000 - Loss: 30.6784 - Val Accuracy: 0.5324
# Epoch 571/1000 - Loss: 30.6287 - Val Accuracy: 0.5286
# Epoch 572/1000 - Loss: 30.5810 - Val Accuracy: 0.5324
# Epoch 573/1000 - Loss: 30.5352 - Val Accuracy: 0.5363
# Epoch 574/1000 - Loss: 30.4877 - Val Accuracy: 0.5363
# Epoch 575/1000 - Loss: 30.4402 - Val Accuracy: 0.5363
# Epoch 576/1000 - Loss: 30.3913 - Val Accuracy: 0.5363
# Epoch 577/1000 - Loss: 30.3455 - Val Accuracy: 0.5344
# Epoch 578/1000 - Loss: 30.2956 - Val Accuracy: 0.5363
# Epoch 579/1000 - Loss: 30.2506 - Val Accuracy: 0.5363
# Epoch 580/1000 - Loss: 30.2026 - Val Accuracy: 0.5363
# Epoch 581/1000 - Loss: 30.1542 - Val Accuracy: 0.5363
# Epoch 582/1000 - Loss: 30.1070 - Val Accuracy: 0.5363
# Epoch 583/1000 - Loss: 30.0626 - Val Accuracy: 0.5363
# Epoch 584/1000 - Loss: 30.0140 - Val Accuracy: 0.5382
# Epoch 585/1000 - Loss: 29.9683 - Val Accuracy: 0.5382
# Epoch 586/1000 - Loss: 29.9192 - Val Accuracy: 0.5401
# Epoch 587/1000 - Loss: 29.8720 - Val Accuracy: 0.5458
# Epoch 588/1000 - Loss: 29.8282 - Val Accuracy: 0.5458
# Epoch 589/1000 - Loss: 29.7810 - Val Accuracy: 0.5458
# Epoch 590/1000 - Loss: 29.7343 - Val Accuracy: 0.5458
# Epoch 591/1000 - Loss: 29.6859 - Val Accuracy: 0.5439
# Epoch 592/1000 - Loss: 29.6400 - Val Accuracy: 0.5477
# Epoch 593/1000 - Loss: 29.5955 - Val Accuracy: 0.5477
# Epoch 594/1000 - Loss: 29.5474 - Val Accuracy: 0.5439
# Epoch 595/1000 - Loss: 29.5032 - Val Accuracy: 0.5439
# Epoch 596/1000 - Loss: 29.4553 - Val Accuracy: 0.5458
# Epoch 597/1000 - Loss: 29.4090 - Val Accuracy: 0.5458
# Epoch 598/1000 - Loss: 29.3638 - Val Accuracy: 0.5458
# Epoch 599/1000 - Loss: 29.3175 - Val Accuracy: 0.5439
# Epoch 600/1000 - Loss: 29.2719 - Val Accuracy: 0.5458
# Epoch 601/1000 - Loss: 29.2267 - Val Accuracy: 0.5458
# Epoch 602/1000 - Loss: 29.1807 - Val Accuracy: 0.5458
# Epoch 603/1000 - Loss: 29.1346 - Val Accuracy: 0.5477
# Epoch 604/1000 - Loss: 29.0899 - Val Accuracy: 0.5439
# Epoch 605/1000 - Loss: 29.0447 - Val Accuracy: 0.5420
# Epoch 606/1000 - Loss: 28.9994 - Val Accuracy: 0.5477
# Epoch 607/1000 - Loss: 28.9540 - Val Accuracy: 0.5477
# Epoch 608/1000 - Loss: 28.9091 - Val Accuracy: 0.5458
# Epoch 609/1000 - Loss: 28.8647 - Val Accuracy: 0.5477
# Epoch 610/1000 - Loss: 28.8200 - Val Accuracy: 0.5458
# Epoch 611/1000 - Loss: 28.7746 - Val Accuracy: 0.5458
# Epoch 612/1000 - Loss: 28.7302 - Val Accuracy: 0.5477
# Epoch 613/1000 - Loss: 28.6847 - Val Accuracy: 0.5496
# Epoch 614/1000 - Loss: 28.6426 - Val Accuracy: 0.5515
# Epoch 615/1000 - Loss: 28.5962 - Val Accuracy: 0.5496
# Epoch 616/1000 - Loss: 28.5516 - Val Accuracy: 0.5553
# Epoch 617/1000 - Loss: 28.5070 - Val Accuracy: 0.5534
# Epoch 618/1000 - Loss: 28.4642 - Val Accuracy: 0.5553
# Epoch 619/1000 - Loss: 28.4208 - Val Accuracy: 0.5553
# Epoch 620/1000 - Loss: 28.3750 - Val Accuracy: 0.5553
# Epoch 621/1000 - Loss: 28.3314 - Val Accuracy: 0.5553
# Epoch 622/1000 - Loss: 28.2872 - Val Accuracy: 0.5611
# Epoch 623/1000 - Loss: 28.2436 - Val Accuracy: 0.5611
# Epoch 624/1000 - Loss: 28.2011 - Val Accuracy: 0.5611
# Epoch 625/1000 - Loss: 28.1584 - Val Accuracy: 0.5630
# Epoch 626/1000 - Loss: 28.1135 - Val Accuracy: 0.5630
# Epoch 627/1000 - Loss: 28.0702 - Val Accuracy: 0.5649
# Epoch 628/1000 - Loss: 28.0270 - Val Accuracy: 0.5630
# Epoch 629/1000 - Loss: 27.9836 - Val Accuracy: 0.5649
# Epoch 630/1000 - Loss: 27.9401 - Val Accuracy: 0.5668
# Epoch 631/1000 - Loss: 27.8973 - Val Accuracy: 0.5668
# Epoch 632/1000 - Loss: 27.8572 - Val Accuracy: 0.5687
# Epoch 633/1000 - Loss: 27.8124 - Val Accuracy: 0.5687
# Epoch 634/1000 - Loss: 27.7680 - Val Accuracy: 0.5687
# Epoch 635/1000 - Loss: 27.7267 - Val Accuracy: 0.5687
# Epoch 636/1000 - Loss: 27.6845 - Val Accuracy: 0.5706
# Epoch 637/1000 - Loss: 27.6427 - Val Accuracy: 0.5706
# Epoch 638/1000 - Loss: 27.6013 - Val Accuracy: 0.5706
# Epoch 639/1000 - Loss: 27.5568 - Val Accuracy: 0.5725
# Epoch 640/1000 - Loss: 27.5167 - Val Accuracy: 0.5706
# Epoch 641/1000 - Loss: 27.4738 - Val Accuracy: 0.5744
# Epoch 642/1000 - Loss: 27.4330 - Val Accuracy: 0.5744
# Epoch 643/1000 - Loss: 27.3888 - Val Accuracy: 0.5782
# Epoch 644/1000 - Loss: 27.3472 - Val Accuracy: 0.5725
# Epoch 645/1000 - Loss: 27.3092 - Val Accuracy: 0.5763
# Epoch 646/1000 - Loss: 27.2663 - Val Accuracy: 0.5782
# Epoch 647/1000 - Loss: 27.2227 - Val Accuracy: 0.5782
# Epoch 648/1000 - Loss: 27.1806 - Val Accuracy: 0.5802
# Epoch 649/1000 - Loss: 27.1386 - Val Accuracy: 0.5802
# Epoch 650/1000 - Loss: 27.0994 - Val Accuracy: 0.5802
# Epoch 651/1000 - Loss: 27.0587 - Val Accuracy: 0.5821
# Epoch 652/1000 - Loss: 27.0174 - Val Accuracy: 0.5840
# Epoch 653/1000 - Loss: 26.9768 - Val Accuracy: 0.5840
# Epoch 654/1000 - Loss: 26.9354 - Val Accuracy: 0.5821
# Epoch 655/1000 - Loss: 26.8951 - Val Accuracy: 0.5821
# Epoch 656/1000 - Loss: 26.8548 - Val Accuracy: 0.5859
# Epoch 657/1000 - Loss: 26.8148 - Val Accuracy: 0.5878
# Epoch 658/1000 - Loss: 26.7750 - Val Accuracy: 0.5897
# Epoch 659/1000 - Loss: 26.7336 - Val Accuracy: 0.5916
# Epoch 660/1000 - Loss: 26.6946 - Val Accuracy: 0.5935
# Epoch 661/1000 - Loss: 26.6551 - Val Accuracy: 0.5954
# Epoch 662/1000 - Loss: 26.6146 - Val Accuracy: 0.5916
# Epoch 663/1000 - Loss: 26.5729 - Val Accuracy: 0.5935
# Epoch 664/1000 - Loss: 26.5356 - Val Accuracy: 0.5935
# Epoch 665/1000 - Loss: 26.4936 - Val Accuracy: 0.5935
# Epoch 666/1000 - Loss: 26.4545 - Val Accuracy: 0.5935
# Epoch 667/1000 - Loss: 26.4156 - Val Accuracy: 0.5973
# Epoch 668/1000 - Loss: 26.3752 - Val Accuracy: 0.5973
# Epoch 669/1000 - Loss: 26.3366 - Val Accuracy: 0.5973
# Epoch 670/1000 - Loss: 26.2975 - Val Accuracy: 0.5973
# Epoch 671/1000 - Loss: 26.2578 - Val Accuracy: 0.5973
# Epoch 672/1000 - Loss: 26.2196 - Val Accuracy: 0.5973
# Epoch 673/1000 - Loss: 26.1815 - Val Accuracy: 0.5973
# Epoch 674/1000 - Loss: 26.1398 - Val Accuracy: 0.5973
# Epoch 675/1000 - Loss: 26.1037 - Val Accuracy: 0.5973
# Epoch 676/1000 - Loss: 26.0646 - Val Accuracy: 0.5973
# Epoch 677/1000 - Loss: 26.0254 - Val Accuracy: 0.5973
# Epoch 678/1000 - Loss: 25.9870 - Val Accuracy: 0.5973
# Epoch 679/1000 - Loss: 25.9494 - Val Accuracy: 0.5992
# Epoch 680/1000 - Loss: 25.9090 - Val Accuracy: 0.5992
# Epoch 681/1000 - Loss: 25.8731 - Val Accuracy: 0.6011
# Epoch 682/1000 - Loss: 25.8357 - Val Accuracy: 0.6011
# Epoch 683/1000 - Loss: 25.7975 - Val Accuracy: 0.6031
# Epoch 684/1000 - Loss: 25.7592 - Val Accuracy: 0.6050
# Epoch 685/1000 - Loss: 25.7215 - Val Accuracy: 0.6069
# Epoch 686/1000 - Loss: 25.6844 - Val Accuracy: 0.6069
# Epoch 687/1000 - Loss: 25.6458 - Val Accuracy: 0.6088
# Epoch 688/1000 - Loss: 25.6092 - Val Accuracy: 0.6088
# Epoch 689/1000 - Loss: 25.5734 - Val Accuracy: 0.6145
# Epoch 690/1000 - Loss: 25.5341 - Val Accuracy: 0.6145
# Epoch 691/1000 - Loss: 25.4978 - Val Accuracy: 0.6183
# Epoch 692/1000 - Loss: 25.4596 - Val Accuracy: 0.6183
# Epoch 693/1000 - Loss: 25.4237 - Val Accuracy: 0.6164
# Epoch 694/1000 - Loss: 25.3853 - Val Accuracy: 0.6164
# Epoch 695/1000 - Loss: 25.3498 - Val Accuracy: 0.6126
# Epoch 696/1000 - Loss: 25.3136 - Val Accuracy: 0.6183
# Epoch 697/1000 - Loss: 25.2759 - Val Accuracy: 0.6221
# Epoch 698/1000 - Loss: 25.2407 - Val Accuracy: 0.6221
# Epoch 699/1000 - Loss: 25.2041 - Val Accuracy: 0.6183
# Epoch 700/1000 - Loss: 25.1667 - Val Accuracy: 0.6202
# Epoch 701/1000 - Loss: 25.1317 - Val Accuracy: 0.6240
# Epoch 702/1000 - Loss: 25.0959 - Val Accuracy: 0.6240
# Epoch 703/1000 - Loss: 25.0584 - Val Accuracy: 0.6260
# Epoch 704/1000 - Loss: 25.0227 - Val Accuracy: 0.6240
# Epoch 705/1000 - Loss: 24.9904 - Val Accuracy: 0.6240
# Epoch 706/1000 - Loss: 24.9513 - Val Accuracy: 0.6279
# Epoch 707/1000 - Loss: 24.9167 - Val Accuracy: 0.6317
# Epoch 708/1000 - Loss: 24.8797 - Val Accuracy: 0.6279
# Epoch 709/1000 - Loss: 24.8452 - Val Accuracy: 0.6298
# Epoch 710/1000 - Loss: 24.8080 - Val Accuracy: 0.6260
# Epoch 711/1000 - Loss: 24.7737 - Val Accuracy: 0.6298
# Epoch 712/1000 - Loss: 24.7402 - Val Accuracy: 0.6317
# Epoch 713/1000 - Loss: 24.7058 - Val Accuracy: 0.6317
# Epoch 714/1000 - Loss: 24.6699 - Val Accuracy: 0.6317
# Epoch 715/1000 - Loss: 24.6374 - Val Accuracy: 0.6317
# Epoch 716/1000 - Loss: 24.5996 - Val Accuracy: 0.6317
# Epoch 717/1000 - Loss: 24.5653 - Val Accuracy: 0.6317
# Epoch 718/1000 - Loss: 24.5287 - Val Accuracy: 0.6317
# Epoch 719/1000 - Loss: 24.4949 - Val Accuracy: 0.6317
# Epoch 720/1000 - Loss: 24.4611 - Val Accuracy: 0.6317
# Epoch 721/1000 - Loss: 24.4275 - Val Accuracy: 0.6317
# Epoch 722/1000 - Loss: 24.3941 - Val Accuracy: 0.6336
# Epoch 723/1000 - Loss: 24.3581 - Val Accuracy: 0.6336
# Epoch 724/1000 - Loss: 24.3239 - Val Accuracy: 0.6317
# Epoch 725/1000 - Loss: 24.2916 - Val Accuracy: 0.6336
# Epoch 726/1000 - Loss: 24.2573 - Val Accuracy: 0.6355
# Epoch 727/1000 - Loss: 24.2221 - Val Accuracy: 0.6355
# Epoch 728/1000 - Loss: 24.1889 - Val Accuracy: 0.6355
# Epoch 729/1000 - Loss: 24.1577 - Val Accuracy: 0.6355
# Epoch 730/1000 - Loss: 24.1217 - Val Accuracy: 0.6336
# Epoch 731/1000 - Loss: 24.0896 - Val Accuracy: 0.6355
# Epoch 732/1000 - Loss: 24.0551 - Val Accuracy: 0.6355
# Epoch 733/1000 - Loss: 24.0245 - Val Accuracy: 0.6393
# Epoch 734/1000 - Loss: 23.9885 - Val Accuracy: 0.6374
# Epoch 735/1000 - Loss: 23.9584 - Val Accuracy: 0.6374
# Epoch 736/1000 - Loss: 23.9244 - Val Accuracy: 0.6374
# Epoch 737/1000 - Loss: 23.8901 - Val Accuracy: 0.6393
# Epoch 738/1000 - Loss: 23.8564 - Val Accuracy: 0.6393
# Epoch 739/1000 - Loss: 23.8264 - Val Accuracy: 0.6431
# Epoch 740/1000 - Loss: 23.7923 - Val Accuracy: 0.6450
# Epoch 741/1000 - Loss: 23.7582 - Val Accuracy: 0.6431
# Epoch 742/1000 - Loss: 23.7283 - Val Accuracy: 0.6431
# Epoch 743/1000 - Loss: 23.6940 - Val Accuracy: 0.6469
# Epoch 744/1000 - Loss: 23.6630 - Val Accuracy: 0.6469
# Epoch 745/1000 - Loss: 23.6293 - Val Accuracy: 0.6469
# Epoch 746/1000 - Loss: 23.5981 - Val Accuracy: 0.6489
# Epoch 747/1000 - Loss: 23.5659 - Val Accuracy: 0.6546
# Epoch 748/1000 - Loss: 23.5339 - Val Accuracy: 0.6527
# Epoch 749/1000 - Loss: 23.5007 - Val Accuracy: 0.6546
# Epoch 750/1000 - Loss: 23.4693 - Val Accuracy: 0.6546
# Epoch 751/1000 - Loss: 23.4399 - Val Accuracy: 0.6546
# Epoch 752/1000 - Loss: 23.4056 - Val Accuracy: 0.6546
# Epoch 753/1000 - Loss: 23.3753 - Val Accuracy: 0.6565
# Epoch 754/1000 - Loss: 23.3472 - Val Accuracy: 0.6565
# Epoch 755/1000 - Loss: 23.3123 - Val Accuracy: 0.6584
# Epoch 756/1000 - Loss: 23.2802 - Val Accuracy: 0.6584
# Epoch 757/1000 - Loss: 23.2511 - Val Accuracy: 0.6584
# Epoch 758/1000 - Loss: 23.2179 - Val Accuracy: 0.6584
# Epoch 759/1000 - Loss: 23.1881 - Val Accuracy: 0.6584
# Epoch 760/1000 - Loss: 23.1589 - Val Accuracy: 0.6603
# Epoch 761/1000 - Loss: 23.1272 - Val Accuracy: 0.6584
# Epoch 762/1000 - Loss: 23.0971 - Val Accuracy: 0.6622
# Epoch 763/1000 - Loss: 23.0634 - Val Accuracy: 0.6622
# Epoch 764/1000 - Loss: 23.0336 - Val Accuracy: 0.6679
# Epoch 765/1000 - Loss: 23.0046 - Val Accuracy: 0.6679
# Epoch 766/1000 - Loss: 22.9732 - Val Accuracy: 0.6737
# Epoch 767/1000 - Loss: 22.9436 - Val Accuracy: 0.6718
# Epoch 768/1000 - Loss: 22.9113 - Val Accuracy: 0.6698
# Epoch 769/1000 - Loss: 22.8795 - Val Accuracy: 0.6756
# Epoch 770/1000 - Loss: 22.8501 - Val Accuracy: 0.6756
# Epoch 771/1000 - Loss: 22.8222 - Val Accuracy: 0.6775
# Epoch 772/1000 - Loss: 22.7911 - Val Accuracy: 0.6775
# Epoch 773/1000 - Loss: 22.7615 - Val Accuracy: 0.6794
# Epoch 774/1000 - Loss: 22.7315 - Val Accuracy: 0.6794
# Epoch 775/1000 - Loss: 22.7017 - Val Accuracy: 0.6775
# Epoch 776/1000 - Loss: 22.6703 - Val Accuracy: 0.6794
# Epoch 777/1000 - Loss: 22.6410 - Val Accuracy: 0.6794
# Epoch 778/1000 - Loss: 22.6126 - Val Accuracy: 0.6794
# Epoch 779/1000 - Loss: 22.5825 - Val Accuracy: 0.6851
# Epoch 780/1000 - Loss: 22.5511 - Val Accuracy: 0.6851
# Epoch 781/1000 - Loss: 22.5220 - Val Accuracy: 0.6851
# Epoch 782/1000 - Loss: 22.4951 - Val Accuracy: 0.6927
# Epoch 783/1000 - Loss: 22.4656 - Val Accuracy: 0.6908
# Epoch 784/1000 - Loss: 22.4376 - Val Accuracy: 0.6908
# Epoch 785/1000 - Loss: 22.4081 - Val Accuracy: 0.6966
# Epoch 786/1000 - Loss: 22.3787 - Val Accuracy: 0.7004
# Epoch 787/1000 - Loss: 22.3485 - Val Accuracy: 0.6927
# Epoch 788/1000 - Loss: 22.3207 - Val Accuracy: 0.7023
# Epoch 789/1000 - Loss: 22.2919 - Val Accuracy: 0.7023
# Epoch 790/1000 - Loss: 22.2628 - Val Accuracy: 0.7042
# Epoch 791/1000 - Loss: 22.2366 - Val Accuracy: 0.7061
# Epoch 792/1000 - Loss: 22.2057 - Val Accuracy: 0.7099
# Epoch 793/1000 - Loss: 22.1782 - Val Accuracy: 0.7099
# Epoch 794/1000 - Loss: 22.1485 - Val Accuracy: 0.7080
# Epoch 795/1000 - Loss: 22.1212 - Val Accuracy: 0.7099
# Epoch 796/1000 - Loss: 22.0912 - Val Accuracy: 0.7061
# Epoch 797/1000 - Loss: 22.0646 - Val Accuracy: 0.7118
# Epoch 798/1000 - Loss: 22.0345 - Val Accuracy: 0.7099
# Epoch 799/1000 - Loss: 22.0090 - Val Accuracy: 0.7099
# Epoch 800/1000 - Loss: 21.9777 - Val Accuracy: 0.7099
# Epoch 801/1000 - Loss: 21.9497 - Val Accuracy: 0.7099
# Epoch 802/1000 - Loss: 21.9252 - Val Accuracy: 0.7118
# Epoch 803/1000 - Loss: 21.8958 - Val Accuracy: 0.7118
# Epoch 804/1000 - Loss: 21.8673 - Val Accuracy: 0.7118
# Epoch 805/1000 - Loss: 21.8406 - Val Accuracy: 0.7118
# Epoch 806/1000 - Loss: 21.8134 - Val Accuracy: 0.7118
# Epoch 807/1000 - Loss: 21.7854 - Val Accuracy: 0.7156
# Epoch 808/1000 - Loss: 21.7592 - Val Accuracy: 0.7137
# Epoch 809/1000 - Loss: 21.7303 - Val Accuracy: 0.7137
# Epoch 810/1000 - Loss: 21.7032 - Val Accuracy: 0.7137
# Epoch 811/1000 - Loss: 21.6752 - Val Accuracy: 0.7156
# Epoch 812/1000 - Loss: 21.6483 - Val Accuracy: 0.7214
# Epoch 813/1000 - Loss: 21.6232 - Val Accuracy: 0.7214
# Epoch 814/1000 - Loss: 21.5952 - Val Accuracy: 0.7195
# Epoch 815/1000 - Loss: 21.5666 - Val Accuracy: 0.7195
# Epoch 816/1000 - Loss: 21.5398 - Val Accuracy: 0.7195
# Epoch 817/1000 - Loss: 21.5144 - Val Accuracy: 0.7252
# Epoch 818/1000 - Loss: 21.4881 - Val Accuracy: 0.7252
# Epoch 819/1000 - Loss: 21.4635 - Val Accuracy: 0.7252
# Epoch 820/1000 - Loss: 21.4368 - Val Accuracy: 0.7271
# Epoch 821/1000 - Loss: 21.4078 - Val Accuracy: 0.7252
# Epoch 822/1000 - Loss: 21.3810 - Val Accuracy: 0.7271
# Epoch 823/1000 - Loss: 21.3536 - Val Accuracy: 0.7290
# Epoch 824/1000 - Loss: 21.3310 - Val Accuracy: 0.7309
# Epoch 825/1000 - Loss: 21.3025 - Val Accuracy: 0.7290
# Epoch 826/1000 - Loss: 21.2767 - Val Accuracy: 0.7328
# Epoch 827/1000 - Loss: 21.2479 - Val Accuracy: 0.7290
# Epoch 828/1000 - Loss: 21.2233 - Val Accuracy: 0.7290
# Epoch 829/1000 - Loss: 21.1961 - Val Accuracy: 0.7309
# Epoch 830/1000 - Loss: 21.1715 - Val Accuracy: 0.7309
# Epoch 831/1000 - Loss: 21.1450 - Val Accuracy: 0.7290
# Epoch 832/1000 - Loss: 21.1195 - Val Accuracy: 0.7271
# Epoch 833/1000 - Loss: 21.0957 - Val Accuracy: 0.7309
# Epoch 834/1000 - Loss: 21.0703 - Val Accuracy: 0.7347
# Epoch 835/1000 - Loss: 21.0421 - Val Accuracy: 0.7385
# Epoch 836/1000 - Loss: 21.0152 - Val Accuracy: 0.7366
# Epoch 837/1000 - Loss: 20.9908 - Val Accuracy: 0.7385
# Epoch 838/1000 - Loss: 20.9633 - Val Accuracy: 0.7385
# Epoch 839/1000 - Loss: 20.9392 - Val Accuracy: 0.7385
# Epoch 840/1000 - Loss: 20.9130 - Val Accuracy: 0.7366
# Epoch 841/1000 - Loss: 20.8892 - Val Accuracy: 0.7366
# Epoch 842/1000 - Loss: 20.8630 - Val Accuracy: 0.7405
# Epoch 843/1000 - Loss: 20.8377 - Val Accuracy: 0.7405
# Epoch 844/1000 - Loss: 20.8118 - Val Accuracy: 0.7424
# Epoch 845/1000 - Loss: 20.7882 - Val Accuracy: 0.7462
# Epoch 846/1000 - Loss: 20.7619 - Val Accuracy: 0.7443
# Epoch 847/1000 - Loss: 20.7376 - Val Accuracy: 0.7500
# Epoch 848/1000 - Loss: 20.7116 - Val Accuracy: 0.7481
# Epoch 849/1000 - Loss: 20.6892 - Val Accuracy: 0.7443
# Epoch 850/1000 - Loss: 20.6630 - Val Accuracy: 0.7462
# Epoch 851/1000 - Loss: 20.6387 - Val Accuracy: 0.7481
# Epoch 852/1000 - Loss: 20.6142 - Val Accuracy: 0.7424
# Epoch 853/1000 - Loss: 20.5878 - Val Accuracy: 0.7500
# Epoch 854/1000 - Loss: 20.5660 - Val Accuracy: 0.7519
# Epoch 855/1000 - Loss: 20.5385 - Val Accuracy: 0.7519
# Epoch 856/1000 - Loss: 20.5148 - Val Accuracy: 0.7500
# Epoch 857/1000 - Loss: 20.4917 - Val Accuracy: 0.7500
# Epoch 858/1000 - Loss: 20.4683 - Val Accuracy: 0.7557
# Epoch 859/1000 - Loss: 20.4430 - Val Accuracy: 0.7500
# Epoch 860/1000 - Loss: 20.4159 - Val Accuracy: 0.7500
# Epoch 861/1000 - Loss: 20.3957 - Val Accuracy: 0.7519
# Epoch 862/1000 - Loss: 20.3697 - Val Accuracy: 0.7538
# Epoch 863/1000 - Loss: 20.3440 - Val Accuracy: 0.7538
# Epoch 864/1000 - Loss: 20.3211 - Val Accuracy: 0.7538
# Epoch 865/1000 - Loss: 20.2987 - Val Accuracy: 0.7576
# Epoch 866/1000 - Loss: 20.2720 - Val Accuracy: 0.7557
# Epoch 867/1000 - Loss: 20.2490 - Val Accuracy: 0.7595
# Epoch 868/1000 - Loss: 20.2258 - Val Accuracy: 0.7595
# Epoch 869/1000 - Loss: 20.2019 - Val Accuracy: 0.7595
# Epoch 870/1000 - Loss: 20.1780 - Val Accuracy: 0.7615
# Epoch 871/1000 - Loss: 20.1549 - Val Accuracy: 0.7595
# Epoch 872/1000 - Loss: 20.1299 - Val Accuracy: 0.7634
# Epoch 873/1000 - Loss: 20.1074 - Val Accuracy: 0.7615
# Epoch 874/1000 - Loss: 20.0832 - Val Accuracy: 0.7615
# Epoch 875/1000 - Loss: 20.0612 - Val Accuracy: 0.7634
# Epoch 876/1000 - Loss: 20.0365 - Val Accuracy: 0.7615
# Epoch 877/1000 - Loss: 20.0148 - Val Accuracy: 0.7634
# Epoch 878/1000 - Loss: 19.9892 - Val Accuracy: 0.7634
# Epoch 879/1000 - Loss: 19.9651 - Val Accuracy: 0.7729
# Epoch 880/1000 - Loss: 19.9455 - Val Accuracy: 0.7634
# Epoch 881/1000 - Loss: 19.9206 - Val Accuracy: 0.7691
# Epoch 882/1000 - Loss: 19.8966 - Val Accuracy: 0.7672
# Epoch 883/1000 - Loss: 19.8750 - Val Accuracy: 0.7710
# Epoch 884/1000 - Loss: 19.8521 - Val Accuracy: 0.7691
# Epoch 885/1000 - Loss: 19.8281 - Val Accuracy: 0.7767
# Epoch 886/1000 - Loss: 19.8059 - Val Accuracy: 0.7729
# Epoch 887/1000 - Loss: 19.7815 - Val Accuracy: 0.7767
# Epoch 888/1000 - Loss: 19.7609 - Val Accuracy: 0.7786
# Epoch 889/1000 - Loss: 19.7356 - Val Accuracy: 0.7767
# Epoch 890/1000 - Loss: 19.7121 - Val Accuracy: 0.7729
# Epoch 891/1000 - Loss: 19.6903 - Val Accuracy: 0.7748
# Epoch 892/1000 - Loss: 19.6703 - Val Accuracy: 0.7824
# Epoch 893/1000 - Loss: 19.6472 - Val Accuracy: 0.7805
# Epoch 894/1000 - Loss: 19.6244 - Val Accuracy: 0.7786
# Epoch 895/1000 - Loss: 19.6023 - Val Accuracy: 0.7824
# Epoch 896/1000 - Loss: 19.5788 - Val Accuracy: 0.7882
# Epoch 897/1000 - Loss: 19.5553 - Val Accuracy: 0.7863
# Epoch 898/1000 - Loss: 19.5356 - Val Accuracy: 0.7863
# Epoch 899/1000 - Loss: 19.5109 - Val Accuracy: 0.7844
# Epoch 900/1000 - Loss: 19.4880 - Val Accuracy: 0.7824
# Epoch 901/1000 - Loss: 19.4661 - Val Accuracy: 0.7844
# Epoch 902/1000 - Loss: 19.4450 - Val Accuracy: 0.7882
# Epoch 903/1000 - Loss: 19.4245 - Val Accuracy: 0.7863
# Epoch 904/1000 - Loss: 19.4025 - Val Accuracy: 0.7882
# Epoch 905/1000 - Loss: 19.3823 - Val Accuracy: 0.7863
# Epoch 906/1000 - Loss: 19.3574 - Val Accuracy: 0.7901
# Epoch 907/1000 - Loss: 19.3364 - Val Accuracy: 0.7901
# Epoch 908/1000 - Loss: 19.3147 - Val Accuracy: 0.7882
# Epoch 909/1000 - Loss: 19.2925 - Val Accuracy: 0.7882
# Epoch 910/1000 - Loss: 19.2711 - Val Accuracy: 0.7882
# Epoch 911/1000 - Loss: 19.2486 - Val Accuracy: 0.7882
# Epoch 912/1000 - Loss: 19.2286 - Val Accuracy: 0.7901
# Epoch 913/1000 - Loss: 19.2054 - Val Accuracy: 0.7901
# Epoch 914/1000 - Loss: 19.1818 - Val Accuracy: 0.7882
# Epoch 915/1000 - Loss: 19.1625 - Val Accuracy: 0.7882
# Epoch 916/1000 - Loss: 19.1411 - Val Accuracy: 0.7901
# Epoch 917/1000 - Loss: 19.1199 - Val Accuracy: 0.7901
# Epoch 918/1000 - Loss: 19.0970 - Val Accuracy: 0.7882
# Epoch 919/1000 - Loss: 19.0761 - Val Accuracy: 0.7920
# Epoch 920/1000 - Loss: 19.0548 - Val Accuracy: 0.7939
# Epoch 921/1000 - Loss: 19.0341 - Val Accuracy: 0.7920
# Epoch 922/1000 - Loss: 19.0140 - Val Accuracy: 0.7920
# Epoch 923/1000 - Loss: 18.9914 - Val Accuracy: 0.7939
# Epoch 924/1000 - Loss: 18.9720 - Val Accuracy: 0.7920
# Epoch 925/1000 - Loss: 18.9485 - Val Accuracy: 0.7920
# Epoch 926/1000 - Loss: 18.9273 - Val Accuracy: 0.7939
# Epoch 927/1000 - Loss: 18.9047 - Val Accuracy: 0.7920
# Epoch 928/1000 - Loss: 18.8850 - Val Accuracy: 0.7958
# Epoch 929/1000 - Loss: 18.8636 - Val Accuracy: 0.7920
# Epoch 930/1000 - Loss: 18.8432 - Val Accuracy: 0.7958
# Epoch 931/1000 - Loss: 18.8217 - Val Accuracy: 0.7939
# Epoch 932/1000 - Loss: 18.7998 - Val Accuracy: 0.7958
# Epoch 933/1000 - Loss: 18.7816 - Val Accuracy: 0.7977
# Epoch 934/1000 - Loss: 18.7632 - Val Accuracy: 0.7958
# Epoch 935/1000 - Loss: 18.7404 - Val Accuracy: 0.7996
# Epoch 936/1000 - Loss: 18.7192 - Val Accuracy: 0.7996
# Epoch 937/1000 - Loss: 18.6981 - Val Accuracy: 0.7977
# Epoch 938/1000 - Loss: 18.6780 - Val Accuracy: 0.7977
# Epoch 939/1000 - Loss: 18.6576 - Val Accuracy: 0.7996
# Epoch 940/1000 - Loss: 18.6381 - Val Accuracy: 0.7977
# Epoch 941/1000 - Loss: 18.6162 - Val Accuracy: 0.7996
# Epoch 942/1000 - Loss: 18.5957 - Val Accuracy: 0.7996
# Epoch 943/1000 - Loss: 18.5783 - Val Accuracy: 0.7977
# Epoch 944/1000 - Loss: 18.5558 - Val Accuracy: 0.7996
# Epoch 945/1000 - Loss: 18.5349 - Val Accuracy: 0.7977
# Epoch 946/1000 - Loss: 18.5172 - Val Accuracy: 0.7996
# Epoch 947/1000 - Loss: 18.4959 - Val Accuracy: 0.8015
# Epoch 948/1000 - Loss: 18.4757 - Val Accuracy: 0.7996
# Epoch 949/1000 - Loss: 18.4537 - Val Accuracy: 0.7996
# Epoch 950/1000 - Loss: 18.4333 - Val Accuracy: 0.7996
# Epoch 951/1000 - Loss: 18.4138 - Val Accuracy: 0.8034
# Epoch 952/1000 - Loss: 18.3966 - Val Accuracy: 0.8015
# Epoch 953/1000 - Loss: 18.3750 - Val Accuracy: 0.8015
# Epoch 954/1000 - Loss: 18.3540 - Val Accuracy: 0.8015
# Epoch 955/1000 - Loss: 18.3341 - Val Accuracy: 0.8015
# Epoch 956/1000 - Loss: 18.3142 - Val Accuracy: 0.8015
# Epoch 957/1000 - Loss: 18.2958 - Val Accuracy: 0.8015
# Epoch 958/1000 - Loss: 18.2764 - Val Accuracy: 0.8034
# Epoch 959/1000 - Loss: 18.2571 - Val Accuracy: 0.8015
# Epoch 960/1000 - Loss: 18.2354 - Val Accuracy: 0.8034
# Epoch 961/1000 - Loss: 18.2157 - Val Accuracy: 0.8034
# Epoch 962/1000 - Loss: 18.1974 - Val Accuracy: 0.8053
# Epoch 963/1000 - Loss: 18.1795 - Val Accuracy: 0.8053
# Epoch 964/1000 - Loss: 18.1601 - Val Accuracy: 0.8015
# Epoch 965/1000 - Loss: 18.1352 - Val Accuracy: 0.8034
# Epoch 966/1000 - Loss: 18.1195 - Val Accuracy: 0.8034
# Epoch 967/1000 - Loss: 18.0991 - Val Accuracy: 0.8073
# Epoch 968/1000 - Loss: 18.0795 - Val Accuracy: 0.8073
# Epoch 969/1000 - Loss: 18.0589 - Val Accuracy: 0.8053
# Epoch 970/1000 - Loss: 18.0425 - Val Accuracy: 0.8073
# Epoch 971/1000 - Loss: 18.0197 - Val Accuracy: 0.8073
# Epoch 972/1000 - Loss: 18.0021 - Val Accuracy: 0.8073
# Epoch 973/1000 - Loss: 17.9839 - Val Accuracy: 0.8073
# Epoch 974/1000 - Loss: 17.9633 - Val Accuracy: 0.8073
# Epoch 975/1000 - Loss: 17.9442 - Val Accuracy: 0.8092
# Epoch 976/1000 - Loss: 17.9246 - Val Accuracy: 0.8092
# Epoch 977/1000 - Loss: 17.9052 - Val Accuracy: 0.8073
# Epoch 978/1000 - Loss: 17.8882 - Val Accuracy: 0.8092
# Epoch 979/1000 - Loss: 17.8679 - Val Accuracy: 0.8092
# Epoch 980/1000 - Loss: 17.8469 - Val Accuracy: 0.8092
# Epoch 981/1000 - Loss: 17.8304 - Val Accuracy: 0.8092
# Epoch 982/1000 - Loss: 17.8119 - Val Accuracy: 0.8073
# Epoch 983/1000 - Loss: 17.7915 - Val Accuracy: 0.8092
# Epoch 984/1000 - Loss: 17.7728 - Val Accuracy: 0.8111
# Epoch 985/1000 - Loss: 17.7529 - Val Accuracy: 0.8092
# Epoch 986/1000 - Loss: 17.7340 - Val Accuracy: 0.8092
# Epoch 987/1000 - Loss: 17.7158 - Val Accuracy: 0.8111
# Epoch 988/1000 - Loss: 17.6996 - Val Accuracy: 0.8092
# Epoch 989/1000 - Loss: 17.6774 - Val Accuracy: 0.8111
# Epoch 990/1000 - Loss: 17.6608 - Val Accuracy: 0.8130
# Epoch 991/1000 - Loss: 17.6408 - Val Accuracy: 0.8130
# Epoch 992/1000 - Loss: 17.6211 - Val Accuracy: 0.8111
# Epoch 993/1000 - Loss: 17.6022 - Val Accuracy: 0.8111
# Epoch 994/1000 - Loss: 17.5873 - Val Accuracy: 0.8130
# Epoch 995/1000 - Loss: 17.5671 - Val Accuracy: 0.8130
# Epoch 996/1000 - Loss: 17.5487 - Val Accuracy: 0.8149
# Epoch 997/1000 - Loss: 17.5302 - Val Accuracy: 0.8130
# Epoch 998/1000 - Loss: 17.5117 - Val Accuracy: 0.8149
# Epoch 999/1000 - Loss: 17.4922 - Val Accuracy: 0.8149
# Epoch 1000/1000 - Loss: 17.4756 - Val Accuracy: 0.8168
# Final Test Accuracy: 0.7924

# %% [markdown]
# # Task 5
#
# In the code cell below, make a copy of the working code in the cell and wrap it in a function `runexp()` with keyword arguments as follows: `runexp(hidden_dim=1,summary=False,max_epochs=1000)` . The function returns the accuracy of the MLP on the testing data after `max_epochs` of training are complete.
#
# `runexp()` will run the experiment as it runs above:
#  + with the MLP instance having the hidden layer size as specified in the function call
#  + with the `torchsummary.summary()` call printed only if `summary is `True`
#  + with the experiment running for the specified number of epochs.
#
#  You'll run the code in Task 6 below.

# %%
# STUDENT CODE GOES HERE


def runexp(hidden_dim=1,summary=False,max_epochs=1000):
    # add apppropriately modified code from the code cell above

# %% [markdown]
# # Task 6: the last task
#
# In this final task, you're going to explore a _hyperparameter_, namely the size of (number of neurons in) the hidden layer. Depending on the complexity of the task, the number of hidden layer units (and, indeed, the number of hidden layers needed - you can and usually do have more than one) required for good performance is unknown and must be searched for.
#
# Loop from `n`=2 to `n`=21, inclusive, running `runexp(hidden_dim=n)` **ten times** for each value of `n` (200 experiments total). This will probably take a couple of hours with a GPU on colab. Save the ten accuracies obtained for each value of `n`, and when the ten experiments are done, print out `n` the sample mean (`np.mean()`) of the accuracies, and the sample standard deviation (`np.std()`)  of the accuracies.  Comment below on what you see in these numbers. You'd like to see high accuracy and low standard deviation. Does accuracy seem to saturate for some value of `n`? What value is it? Do the standard deviations reach an acceptable level (lower is more acceptable)?
#
# Student Comments:

# %%
nruns_per_hid = 10

for nhid in range(2,22):
    print(f'=== {nhid} hidden units ===')
    accs = [runexp(nhid,summary=(i==0)) for i in range(nruns_per_hid)]
    print(f'accs: {accs}')
    print(f'Mean accuracy: {np.mean(accs)}')
    print(f'Std accuracy: {np.std(accs)}')
# Out:
# === 1 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]             129
#               ReLU-2                    [-1, 1]               0
#             Linear-3                   [-1, 10]              20
# ================================================================
# Total params: 149
# Trainable params: 149
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.1146), tensor(0.1146), tensor(0.2888), tensor(0.2530), tensor(0.1098), tensor(0.1098), tensor(0.2100), tensor(0.2554), tensor(0.3150), tensor(0.3365)]
# Mean accuracy: 0.2107398509979248
# Std accuracy: 0.08686204254627228
# === 2 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]             258
#               ReLU-2                    [-1, 2]               0
#             Linear-3                   [-1, 10]              30
# ================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.3365), tensor(0.1098), tensor(0.3007), tensor(0.5680), tensor(0.5394), tensor(0.5871), tensor(0.3198), tensor(0.5728), tensor(0.1098), tensor(0.6993)]
# Mean accuracy: 0.41431981325149536
# Std accuracy: 0.19718341529369354
# === 3 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]             387
#               ReLU-2                    [-1, 3]               0
#             Linear-3                   [-1, 10]              40
# ================================================================
# Total params: 427
# Trainable params: 427
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.5704), tensor(0.2578), tensor(0.6158), tensor(0.5322), tensor(0.6659), tensor(0.5704), tensor(0.1527), tensor(0.5489), tensor(0.2721), tensor(0.7804)]
# Mean accuracy: 0.49665871262550354
# Std accuracy: 0.1907888948917389
# === 4 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 4]             516
#               ReLU-2                    [-1, 4]               0
#             Linear-3                   [-1, 10]              50
# ================================================================
# Total params: 566
# Trainable params: 566
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.7709), tensor(0.8186), tensor(0.2506), tensor(0.5585), tensor(0.6897), tensor(0.5895), tensor(0.3198), tensor(0.6038), tensor(0.3317), tensor(0.6969)]
# Mean accuracy: 0.5630072355270386
# Std accuracy: 0.18845486640930176
# === 5 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 5]             645
#               ReLU-2                    [-1, 5]               0
#             Linear-3                   [-1, 10]              60
# ================================================================
# Total params: 705
# Trainable params: 705
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.6086), tensor(0.7947), tensor(0.7375), tensor(0.8831), tensor(0.8473), tensor(0.6158), tensor(0.6754), tensor(0.8091), tensor(0.8305), tensor(0.8329)]
# Mean accuracy: 0.7634844779968262
# Std accuracy: 0.09377653151750565
# === 6 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 6]             774
#               ReLU-2                    [-1, 6]               0
#             Linear-3                   [-1, 10]              70
# ================================================================
# Total params: 844
# Trainable params: 844
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8663), tensor(0.8234), tensor(0.8138), tensor(0.8544), tensor(0.5871), tensor(0.6754), tensor(0.8282), tensor(0.8282), tensor(0.8067), tensor(0.6468)]
# Mean accuracy: 0.7730310559272766
# Std accuracy: 0.09315492957830429
# === 7 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 7]             903
#               ReLU-2                    [-1, 7]               0
#             Linear-3                   [-1, 10]              80
# ================================================================
# Total params: 983
# Trainable params: 983
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8568), tensor(0.5609), tensor(0.7804), tensor(0.8282), tensor(0.8687), tensor(0.8305), tensor(0.8711), tensor(0.6778), tensor(0.8496), tensor(0.8425)]
# Mean accuracy: 0.7966587543487549
# Std accuracy: 0.09560134261846542
# === 8 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 8]           1,032
#               ReLU-2                    [-1, 8]               0
#             Linear-3                   [-1, 10]              90
# ================================================================
# Total params: 1,122
# Trainable params: 1,122
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8425), tensor(0.8568), tensor(0.8449), tensor(0.7136), tensor(0.8759), tensor(0.8138), tensor(0.8353), tensor(0.8854), tensor(0.8807), tensor(0.8329)]
# Mean accuracy: 0.8381861448287964
# Std accuracy: 0.0469239316880703
# === 9 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 9]           1,161
#               ReLU-2                    [-1, 9]               0
#             Linear-3                   [-1, 10]             100
# ================================================================
# Total params: 1,261
# Trainable params: 1,261
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8950), tensor(0.7566), tensor(0.8186), tensor(0.8878), tensor(0.8902), tensor(0.8425), tensor(0.9165), tensor(0.8568), tensor(0.8854), tensor(0.8568)]
# Mean accuracy: 0.8606206178665161
# Std accuracy: 0.04413919895887375
# === 10 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 10]           1,290
#               ReLU-2                   [-1, 10]               0
#             Linear-3                   [-1, 10]             110
# ================================================================
# Total params: 1,400
# Trainable params: 1,400
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8926), tensor(0.8735), tensor(0.8998), tensor(0.8663), tensor(0.8998), tensor(0.8926), tensor(0.9069), tensor(0.9021), tensor(0.8711), tensor(0.8902)]
# Mean accuracy: 0.8894988894462585
# Std accuracy: 0.013502949848771095
# === 11 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 11]           1,419
#               ReLU-2                   [-1, 11]               0
#             Linear-3                   [-1, 10]             120
# ================================================================
# Total params: 1,539
# Trainable params: 1,539
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.9212), tensor(0.8663), tensor(0.8878), tensor(0.8950), tensor(0.9093), tensor(0.9093), tensor(0.7852), tensor(0.9093), tensor(0.9045), tensor(0.8759)]
# Mean accuracy: 0.8863962292671204
# Std accuracy: 0.03734453395009041
# === 12 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 12]           1,548
#               ReLU-2                   [-1, 12]               0
#             Linear-3                   [-1, 10]             130
# ================================================================
# Total params: 1,678
# Trainable params: 1,678
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8926), tensor(0.9117), tensor(0.8878), tensor(0.8496), tensor(0.8162), tensor(0.9117), tensor(0.8902), tensor(0.9045), tensor(0.8926), tensor(0.8807)]
# Mean accuracy: 0.8837709426879883
# Std accuracy: 0.02817947044968605
# === 13 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 13]           1,677
#               ReLU-2                   [-1, 13]               0
#             Linear-3                   [-1, 10]             140
# ================================================================
# Total params: 1,817
# Trainable params: 1,817
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.9045), tensor(0.9117), tensor(0.8663), tensor(0.9093), tensor(0.9141), tensor(0.9069), tensor(0.8950), tensor(0.9141), tensor(0.8974), tensor(0.9189)]
# Mean accuracy: 0.9038187265396118
# Std accuracy: 0.014361504465341568
# === 14 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 14]           1,806
#               ReLU-2                   [-1, 14]               0
#             Linear-3                   [-1, 10]             150
# ================================================================
# Total params: 1,956
# Trainable params: 1,956
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.9021), tensor(0.9069), tensor(0.9045), tensor(0.9021), tensor(0.8902), tensor(0.9021), tensor(0.8807), tensor(0.8878), tensor(0.8998), tensor(0.8592)]
# Mean accuracy: 0.8935559988021851
# Std accuracy: 0.01396538969129324
# === 15 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 15]           1,935
#               ReLU-2                   [-1, 15]               0
#             Linear-3                   [-1, 10]             160
# ================================================================
# Total params: 2,095
# Trainable params: 2,095
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8878), tensor(0.8878), tensor(0.8950), tensor(0.8974), tensor(0.8974), tensor(0.8282), tensor(0.9021), tensor(0.8329), tensor(0.8878), tensor(0.9117)]
# Mean accuracy: 0.8828163146972656
# Std accuracy: 0.027074376121163368
# === 16 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 16]           2,064
#               ReLU-2                   [-1, 16]               0
#             Linear-3                   [-1, 10]             170
# ================================================================
# Total params: 2,234
# Trainable params: 2,234
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.9045), tensor(0.8950), tensor(0.9021), tensor(0.8902), tensor(0.9189), tensor(0.8831), tensor(0.9189), tensor(0.9045), tensor(0.9045), tensor(0.9093)]
# Mean accuracy: 0.9031025767326355
# Std accuracy: 0.010842788964509964
# === 17 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 17]           2,193
#               ReLU-2                   [-1, 17]               0
#             Linear-3                   [-1, 10]             180
# ================================================================
# Total params: 2,373
# Trainable params: 2,373
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.8878), tensor(0.9093), tensor(0.9045), tensor(0.9045), tensor(0.9117), tensor(0.9069), tensor(0.9141), tensor(0.9069), tensor(0.9141), tensor(0.9069)]
# Mean accuracy: 0.9066826701164246
# Std accuracy: 0.007116015534847975
# === 18 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 18]           2,322
#               ReLU-2                   [-1, 18]               0
#             Linear-3                   [-1, 10]             190
# ================================================================
# Total params: 2,512
# Trainable params: 2,512
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.9045), tensor(0.9117), tensor(0.9165), tensor(0.9165), tensor(0.9236), tensor(0.9117), tensor(0.8854), tensor(0.9045), tensor(0.9093), tensor(0.9117)]
# Mean accuracy: 0.9095465540885925
# Std accuracy: 0.009691620245575905
# === 19 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 19]           2,451
#               ReLU-2                   [-1, 19]               0
#             Linear-3                   [-1, 10]             200
# ================================================================
# Total params: 2,651
# Trainable params: 2,651
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.9021), tensor(0.8687), tensor(0.8974), tensor(0.9069), tensor(0.9045), tensor(0.9021), tensor(0.9069), tensor(0.9069), tensor(0.9117), tensor(0.8950)]
# Mean accuracy: 0.9002386927604675
# Std accuracy: 0.011485632508993149
# === 20 hidden units ===
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 20]           2,580
#               ReLU-2                   [-1, 20]               0
#             Linear-3                   [-1, 10]             210
# ================================================================
# Total params: 2,790
# Trainable params: 2,790
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# accs: [tensor(0.9189), tensor(0.9045), tensor(0.9069), tensor(0.8950), tensor(0.9141), tensor(0.9021), tensor(0.9117), tensor(0.8902), tensor(0.8735), tensor(0.8878)]
# Mean accuracy: 0.9004772901535034
# Std accuracy: 0.013161158189177513
